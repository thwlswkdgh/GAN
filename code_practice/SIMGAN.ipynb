# %% [markdown]
# <a href="https://colab.research.google.com/github/thwlswkdgh/GAN/blob/main/code_practice/SIMGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 환경설정
# 1. kaggle 접속
# 2. 데이터 다운로드 및 zip파일 풀기

# %%
# !pip install -q kaggle

# %%
# !mkdir -p ~/.kaggle

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3e715208-2ca3-4872-b8b7-535270fd530b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3e715208-2ca3-4872-b8b7-535270fd530b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle datasets list
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# ref                                                         title                                              size  lastUpdated          downloadCount
# ----------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------
# gpreda/reddit-vaccine-myths                                 Reddit Vaccine Myths                              237KB  2021-12-12 11:59:54          18828
# crowww/a-large-scale-fish-dataset                           A Large Scale Fish Dataset                          3GB  2021-04-28 17:03:01          11425
# imsparsh/musicnet-dataset                                   MusicNet Dataset                                   22GB  2021-02-18 14:12:19           5875
# dhruvildave/wikibooks-dataset                               Wikibooks Dataset                                   2GB  2021-10-22 10:48:21           4008
# promptcloud/careerbuilder-job-listing-2020                  Careerbuilder Job Listing 2020                     42MB  2021-03-05 06:59:52           3101
# mathurinache/twitter-edge-nodes                             Twitter Edge Nodes                                342MB  2021-03-08 06:43:04           1515
# fatiimaezzahra/famous-iconic-women                          Famous Iconic Women                               838MB  2021-02-28 14:56:00           2184
# mathurinache/the-lj-speech-dataset                          The LJ Speech Dataset                               3GB  2021-02-15 09:19:54            630
# coloradokb/dandelionimages                                  DandelionImages                                     4GB  2021-02-19 20:03:47           1192
# alsgroup/end-als                                            End ALS Kaggle Challenge                           12GB  2021-04-08 12:16:37           1250
# simiotic/github-code-snippets                               GitHub Code Snippets                                7GB  2021-03-03 11:34:39            581
# imsparsh/accentdb-core-extended                             AccentDB - Core & Extended                          6GB  2021-02-17 14:22:54            213
# stuartjames/lights                                          LightS: Light Specularity Dataset                  18GB  2021-02-18 14:32:26            285
# nickuzmenkov/ranzcr-clip-kfold-tfrecords                    RANZCR CLiP KFold TFRecords                         2GB  2021-02-21 13:29:51            177
# landrykezebou/lvzhdr-tone-mapping-benchmark-dataset-tmonet  LVZ-HDR Tone Mapping Benchmark Dataset (TMO-Net)   24GB  2021-03-01 05:03:40            282
# datasnaek/youtube-new                                       Trending YouTube Video Statistics                 201MB  2019-06-03 00:56:47         163484
# zynicide/wine-reviews                                       Wine Reviews                                       51MB  2017-11-27 17:08:04         152605
# residentmario/ramen-ratings                                 Ramen Ratings                                      40KB  2018-01-11 16:04:39          31834
# datasnaek/chess                                             Chess Game Dataset (Lichess)                        3MB  2017-09-04 03:09:09          27000
# rtatman/188-million-us-wildfires                            1.88 Million US Wildfires                         168MB  2020-05-12 21:03:49          18570

# %%
# !kaggle datasets download -d 4quant/eye-gaze -p /data/
# Out:
# Downloading eye-gaze.zip to /data
# 100% 4.45G/4.46G [01:21<00:00, 91.1MB/s]
# 100% 4.46G/4.46G [01:22<00:00, 58.4MB/s]

# %%
# !unzip /data/eye-gaze.zip -d eye-gaze

# %%
# !git clone https://github.com/PacktPublishing/Generative-Adversarial-Networks-Cookbook.git
# !mkdir out
# Out:
# Cloning into 'Generative-Adversarial-Networks-Cookbook'...
# remote: Enumerating objects: 177, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 177 (delta 1), reused 0 (delta 0), pack-reused 172
# Receiving objects: 100% (177/177), 94.49 KiB | 3.05 MiB/s, done.
# Resolving deltas: 100% (51/51), done.

# %% [markdown]
# ### 손실함수
# 1. self regulation loss
# 2. local adversarial loss

# %%
#!/usr/bin/env python3
import tensorflow as tf


def self_regularization_loss(y_true,y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return tf.multiply(0.0002,tf.reduce_sum(tf.abs(y_pred-y_true)))

def local_adversarial_loss(y_true,y_pred):
    truth = tf.reshape(y_true,(-1,2))
    predicted = tf.reshape(y_pred,(-1,2))

    computed_loss = tf.nn.softmax_cross_entropy_with_logits(labels=truth,logits=predicted)
    output = tf.reduce_mean(computed_loss)
    return output

# %% [markdown]
# ### 판별기

# %%
#!/usr/bin/env python3
import sys
import numpy as np
from keras.layers import Input, Dense, Reshape, Flatten, Dropout, BatchNormalization, Lambda, Concatenate, MaxPooling2D
from keras.layers.core import Activation
from keras.layers.convolutional import Convolution2D
from keras.layers.advanced_activations import LeakyReLU
from keras.activations import relu
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam, SGD,Nadam, Adamax
from tensorflow.keras.utils import plot_model
import tensorflow as tf



class Discriminator(object):
    def __init__(self, width = 35, height= 55, channels = 1,name='discriminator'):
        self.W = width
        self.H = height
        self.C = channels
        self.SHAPE = (height,width,channels)
        self.NAME = name
        
        self.Discriminator = self.model()
        self.OPTIMIZER = SGD(learning_rate=0.001)
        self.Discriminator.compile(loss=local_adversarial_loss, optimizer=self.OPTIMIZER)

        self.save_model_graph()
        self.summary()
#model.add(Convolution2D(64, kernel_size= 5, strides= 2, input_shape=(self.W,self.H,self.C), padding='same',activation=LeakyReLU(alpha=0.2)))
    def model(self):
        input_layer = Input(shape=self.SHAPE)
        x = Convolution2D(96,kernel_size= 3, strides =2, padding='same',activation='relu')(input_layer)
        x = Convolution2D(64,kernel_size= 3, strides =2, padding='same',activation='relu')(x)
        x = MaxPooling2D(pool_size=(3,3),padding='same')(x)
        x = Convolution2D(32,kernel_size= 3, strides =1, padding='same',activation='relu')(x)
        x = Convolution2D(32,kernel_size= 1, strides =1, padding='same',activation='relu')(x)
        x = Convolution2D(2,kernel_size= 1, strides =1, padding='same',activation='relu')(x)
        output_layer = Reshape((-1,2))(x)
        return Model(input_layer,output_layer) 

    def summary(self):
        return self.Discriminator.summary()

    def save_model_graph(self):
        plot_model(self.Discriminator, to_file='/data/Discriminator_Model.png')

    def save_model(self,epoch,batch):
        self.Discriminator.save('/data/'+self.NAME+'_Epoch_'+epoch+'_Batch_'+batch+'model.h5')
d = Discriminator()
# Out:
# Model: "model_52"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_69 (InputLayer)       [(None, 55, 35, 1)]       0
#
#  conv2d_297 (Conv2D)         (None, 28, 18, 96)        960
#
#  conv2d_298 (Conv2D)         (None, 14, 9, 64)         55360
#
#  max_pooling2d_19 (MaxPoolin  (None, 5, 3, 64)         0
#  g2D)
#
#  conv2d_299 (Conv2D)         (None, 5, 3, 32)          18464
#
#  conv2d_300 (Conv2D)         (None, 5, 3, 32)          1056
#
#  conv2d_301 (Conv2D)         (None, 5, 3, 2)           66
#
#  reshape_19 (Reshape)        (None, 15, 2)             0
#
# =================================================================
# Total params: 75,906
# Trainable params: 75,906
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ###생성기

# %%
import sys
import numpy as np
from keras.layers import Dense, Reshape, Input, BatchNormalization, Concatenate, Activation
from keras.layers.core import Activation
from keras.layers.convolutional import UpSampling2D, Convolution2D, MaxPooling2D,Deconvolution2D, Conv2D
from keras.layers.advanced_activations import LeakyReLU
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam, SGD, Nadam,Adamax
from keras import initializers
from keras import layers
import tensorflow as tf


class Generator(object):
    def __init__(self, width = 35, height= 55, channels = 1,name='generator'):
        
        self.W = width
        self.H = height
        self.C = channels
        self.SHAPE = (height,width,channels)
        self.NAME = name

        self.Generator = self.model()
        self.OPTIMIZER = SGD(learning_rate=0.001)
        self.Generator.compile(loss=self_regularization_loss, optimizer=self.OPTIMIZER)

        self.save_model_graph()
        self.summary()

    def model(self):
        # Input
        input_layer = Input(shape=self.SHAPE)
        x = Convolution2D(64, kernel_size= 3, padding='same',activation='relu')(input_layer)

        # ResNet Block 1
        res_x_input_1 = Conv2D(64, kernel_size= 3, padding='same',activation='relu')(x)
        x = Convolution2D(64, kernel_size= 3, padding='same',activation='relu')(res_x_input_1)
        x = layers.Add()([res_x_input_1,x])
        x = Activation('relu')(x)

        # ResNet Block 2
        res_x_input_2 = Conv2D(64, kernel_size= 3, padding='same',activation='relu')(x)
        x = Convolution2D(64, kernel_size= 3, padding='same',activation='relu')(res_x_input_2)
        x = layers.Add()([res_x_input_2,x])
        x = Activation('relu')(x)

        # ResNet Block 3
        res_x_input_3 = Conv2D(64, kernel_size= 3, padding='same',activation='relu')(x)
        x = Convolution2D(64,kernel_size= 3, padding='same',activation='relu')(res_x_input_3)
        x = layers.Add()([res_x_input_3,x])
        x = Activation('relu')(x)

        # ResNet Block 4
        res_x_input_4 = Conv2D(64, kernel_size= 3, padding='same',activation='relu')(x)
        x = Convolution2D(64,kernel_size= 3, padding='same',activation='relu')(res_x_input_4)
        x = layers.Add()([res_x_input_4,x])
        x = Activation('relu')(x)

        output_layer = Convolution2D(self.C,kernel_size= 1, padding='same',activation='tanh')(x)
        
        return Model(input_layer,output_layer)

    def summary(self):
        return self.Generator.summary()

    def save_model_graph(self):
        plot_model(self.Generator, to_file='/data/Generator_Model.png')
    
    def save_model(self,epoch,batch):
        self.Generator.save('/data/'+self.NAME+'_Epoch_'+epoch+'_Batch_'+batch+'model.h5')
g=Generator()
# Out:
# Model: "model_53"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_70 (InputLayer)          [(None, 55, 35, 1)]  0           []
#
#  conv2d_302 (Conv2D)            (None, 55, 35, 64)   640         ['input_70[0][0]']
#
#  conv2d_303 (Conv2D)            (None, 55, 35, 64)   36928       ['conv2d_302[0][0]']
#
#  conv2d_304 (Conv2D)            (None, 55, 35, 64)   36928       ['conv2d_303[0][0]']
#
#  add_80 (Add)                   (None, 55, 35, 64)   0           ['conv2d_303[0][0]',
#                                                                   'conv2d_304[0][0]']
#
#  activation_80 (Activation)     (None, 55, 35, 64)   0           ['add_80[0][0]']
#
#  conv2d_305 (Conv2D)            (None, 55, 35, 64)   36928       ['activation_80[0][0]']
#
#  conv2d_306 (Conv2D)            (None, 55, 35, 64)   36928       ['conv2d_305[0][0]']
#
#  add_81 (Add)                   (None, 55, 35, 64)   0           ['conv2d_305[0][0]',
#                                                                   'conv2d_306[0][0]']
#
#  activation_81 (Activation)     (None, 55, 35, 64)   0           ['add_81[0][0]']
#
#  conv2d_307 (Conv2D)            (None, 55, 35, 64)   36928       ['activation_81[0][0]']
#
#  conv2d_308 (Conv2D)            (None, 55, 35, 64)   36928       ['conv2d_307[0][0]']
#
#  add_82 (Add)                   (None, 55, 35, 64)   0           ['conv2d_307[0][0]',
#                                                                   'conv2d_308[0][0]']
#
#  activation_82 (Activation)     (None, 55, 35, 64)   0           ['add_82[0][0]']
#
#  conv2d_309 (Conv2D)            (None, 55, 35, 64)   36928       ['activation_82[0][0]']
#
#  conv2d_310 (Conv2D)            (None, 55, 35, 64)   36928       ['conv2d_309[0][0]']
#
#  add_83 (Add)                   (None, 55, 35, 64)   0           ['conv2d_309[0][0]',
#                                                                   'conv2d_310[0][0]']
#
#  activation_83 (Activation)     (None, 55, 35, 64)   0           ['add_83[0][0]']
#
#  conv2d_311 (Conv2D)            (None, 55, 35, 1)    65          ['activation_83[0][0]']
#
# ==================================================================================================
# Total params: 296,129
# Trainable params: 296,129
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### GAN

# %%
#!/usr/bin/env python3
import sys
import numpy as np
from keras.models import Sequential, Model
from keras.layers import Input
import tensorflow as tf


class GAN(object):
    def __init__(self, model_inputs=[],model_outputs=[], name='gan'):
        self.OPTIMIZER = SGD(learning_rate=2e-4,nesterov=True)
        self.NAME=name

        self.inputs = model_inputs
        self.outputs = model_outputs
        self.gan_model = Model(inputs = self.inputs, outputs = self.outputs)
        self.OPTIMIZER = SGD(learning_rate=0.001)
        self.gan_model.compile(loss=[self_regularization_loss, self_regularization_loss],
                            optimizer=self.OPTIMIZER)
        self.save_model_graph()
        self.summary()

    def summary(self):
        return self.gan_model.summary()

    def save_model_graph(self):
        plot_model(self.gan_model, to_file='/data/GAN_Model.png')

    def save_model(self,epoch,batch):
        self.gan_model.save('/data/'+self.NAME+'_Epoch_'+epoch+'_Batch_'+batch+'model.h5')

    def self_regularization_loss(self,y_true,y_pred):
        return tf.multiply(0.0002,tf.reduce_sum(tf.abs(y_pred-y_true)))

    def local_adversarial_loss(self,y_true,y_pred):
        truth = tf.reshape(y_true,(-1,2))
        predicted = tf.reshape(y_pred,(-1,2))

        computed_loss = tf.nn.softmax_cross_entropy_with_logits(labels=truth,logits=predicted)
        output = tf.reduce_mean(computed_loss)
        return output

# %% [markdown]
# ###Train

# %%
#!/usr/bin/env python3
from keras.datasets import mnist
from keras.layers import Input
from random import randint
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os
import numpy as np
from copy import deepcopy

class Trainer:
    def __init__(self, height=55,width=35, channels=1,epochs =100, batch=16, checkpoint=50,sim_path='',real_path='',data_limit=0.001,generator_steps=2,discriminator_steps=1):
        self.W = width
        self.H = height
        self.C = channels
        self.EPOCHS = epochs
        self.BATCH = batch
        self.CHECKPOINT = checkpoint
        self.DATA_LIMIT=data_limit
        self.GEN_STEPS = generator_steps
        self.DISC_STEPS = discriminator_steps

        self.X_real = self.load_h5py(real_path)
        self.X_sim = self.load_h5py(sim_path)

        self.refiner = Generator(height=self.H, width=self.W, channels=self.C)
        self.discriminator = Discriminator(height=self.H, width=self.W, channels=self.C)
        self.discriminator.trainable = False

        self.synthetic_image = Input(shape=(self.H, self.W, self.C))
        self.real_or_fake = Input(shape=(self.H, self.W, self.C))


        self.refined_image = self.refiner.Generator(self.synthetic_image)
        self.discriminator_output = self.discriminator.Discriminator(self.real_or_fake)
        self.combined = self.discriminator.Discriminator(self.refined_image)

        model_inputs  = [self.synthetic_image]
        model_outputs = [self.refined_image, self.combined]
        self.gan = GAN(model_inputs=model_inputs,model_outputs=model_outputs)

    def load_h5py(self,data_path):
        with h5py.File(data_path,'r') as t_file:
            print('Images found:',len(t_file['image']))
            image_stack = np.stack([np.expand_dims(a,-1) for a in t_file['image'].values()],0)
        return image_stack

    def train(self):
        for e in range(self.EPOCHS):

            b = 0
            X_real_temp = deepcopy(self.X_real)
            X_sim_temp = deepcopy(self.X_sim)
            combined_loss = np.zeros(shape=len(self.gan.gan_model.metrics_names))
            discriminator_loss_real = np.zeros(shape=len(self.discriminator.Discriminator.metrics_names))
            discriminator_loss_sim = np.zeros(shape=len(self.discriminator.Discriminator.metrics_names))

            while b < self.BATCH:
                # Keep track of Batches
                b=b+1

                count_real_images = int(self.BATCH)
                starting_indexs = randint(0, (min(len(X_real_temp),len(X_sim_temp))-count_real_images))
              
                real_images_raw = X_real_temp[ starting_indexs : (starting_indexs + count_real_images) ]
                real_images = real_images_raw.reshape( count_real_images, self.H, self.W, self.C )

                y_real = np.array([[[1.0, 0.0]] * self.discriminator.Discriminator.output_shape[1]] * self.BATCH)
                
                sim_images_raw = X_sim_temp[ starting_indexs : (starting_indexs + count_real_images) ]
                sim_images = sim_images_raw.reshape( count_real_images, self.H, self.W, self.C )

                y_sim = np.array([[[0.0, 1.0]] * self.discriminator.Discriminator.output_shape[1]] * self.BATCH)
                gen_step_first = True
                for _ in range(self.GEN_STEPS):
                  if gen_step_first==True:
                    gen_step_first=False
                    combined_loss = self.gan.gan_model.train_on_batch(sim_images,[sim_images, y_real])
                  else:
                    combined_loss = np.add(self.gan.gan_model.train_on_batch(sim_images,[sim_images, y_real]), combined_loss)
        
                dis_step_first = True
                for _ in range(self.DISC_STEPS):
                  improved_image_batch = self.refiner.Generator.predict_on_batch(sim_images)
                  if dis_step_first==True:
                    dis_step_first = False
                    discriminator_loss_real = self.discriminator.Discriminator.train_on_batch(real_images, y_real)
                    discriminator_loss_sim = self.discriminator.Discriminator.train_on_batch(improved_image_batch, y_sim)
                  else:
                    discriminator_loss_real = np.add(self.discriminator.Discriminator.train_on_batch(real_images, y_real), discriminator_loss_real)
                    discriminator_loss_sim = np.add(self.discriminator.Discriminator.train_on_batch(improved_image_batch, y_sim),discriminator_loss_sim)

                print ('Epoch: '+str(int(e))+', [Real Discriminator :: Loss: '+str(discriminator_loss_real)+'], [ GAN :: Loss: '+str(combined_loss)+']')
                        
        return

# %% [markdown]
# ###Run

# %%
#!/usr/bin/env python3
import h5py

# Command Line Argument Method
HEIGHT  = 55
WIDTH   = 35
CHANNELS = 1
EPOCHS = 100
BATCH = 16
CHECKPOINT = 50
SIM_PATH = "/content/eye-gaze/gaze.h5"
REAL_PATH = "/content/eye-gaze/real_gaze.h5"

trainer = Trainer(height=HEIGHT,width=WIDTH, channels=CHANNELS,epochs =EPOCHS,\
                 batch=BATCH,\
                 checkpoint=CHECKPOINT,\
                 sim_path=SIM_PATH,\
                 real_path=REAL_PATH)
trainer.train()
# Out:
# Images found: 34100
# Images found: 50000
# Model: "model_60"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_79 (InputLayer)          [(None, 55, 35, 1)]  0           []
#
#  conv2d_342 (Conv2D)            (None, 55, 35, 64)   640         ['input_79[0][0]']
#
#  conv2d_343 (Conv2D)            (None, 55, 35, 64)   36928       ['conv2d_342[0][0]']
#
#  conv2d_344 (Conv2D)            (None, 55, 35, 64)   36928       ['conv2d_343[0][0]']
#
#  add_92 (Add)                   (None, 55, 35, 64)   0           ['conv2d_343[0][0]',
#                                                                   'conv2d_344[0][0]']
#
#  activation_92 (Activation)     (None, 55, 35, 64)   0           ['add_92[0][0]']
#
#  conv2d_345 (Conv2D)            (None, 55, 35, 64)   36928       ['activation_92[0][0]']
#
#  conv2d_346 (Conv2D)            (None, 55, 35, 64)   36928       ['conv2d_345[0][0]']
#
#  add_93 (Add)                   (None, 55, 35, 64)   0           ['conv2d_345[0][0]',
#                                                                   'conv2d_346[0][0]']
#
#  activation_93 (Activation)     (None, 55, 35, 64)   0           ['add_93[0][0]']
#
#  conv2d_347 (Conv2D)            (None, 55, 35, 64)   36928       ['activation_93[0][0]']
#
#  conv2d_348 (Conv2D)            (None, 55, 35, 64)   36928       ['conv2d_347[0][0]']
#
#  add_94 (Add)                   (None, 55, 35, 64)   0           ['conv2d_347[0][0]',
#                                                                   'conv2d_348[0][0]']
#
#  activation_94 (Activation)     (None, 55, 35, 64)   0           ['add_94[0][0]']
#
#  conv2d_349 (Conv2D)            (None, 55, 35, 64)   36928       ['activation_94[0][0]']
#
#  conv2d_350 (Conv2D)            (None, 55, 35, 64)   36928       ['conv2d_349[0][0]']
#
#  add_95 (Add)                   (None, 55, 35, 64)   0           ['conv2d_349[0][0]',
#                                                                   'conv2d_350[0][0]']
#
#  activation_95 (Activation)     (None, 55, 35, 64)   0           ['add_95[0][0]']
#
#  conv2d_351 (Conv2D)            (None, 55, 35, 1)    65          ['activation_95[0][0]']
#
# ==================================================================================================
# Total params: 296,129
# Trainable params: 296,129
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_61"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_80 (InputLayer)       [(None, 55, 35, 1)]       0
#
#  conv2d_352 (Conv2D)         (None, 28, 18, 96)        960
#
#  conv2d_353 (Conv2D)         (None, 14, 9, 64)         55360
#
#  max_pooling2d_22 (MaxPoolin  (None, 5, 3, 64)         0
#  g2D)
#
#  conv2d_354 (Conv2D)         (None, 5, 3, 32)          18464
#
#  conv2d_355 (Conv2D)         (None, 5, 3, 32)          1056
#
#  conv2d_356 (Conv2D)         (None, 5, 3, 2)           66
#
#  reshape_22 (Reshape)        (None, 15, 2)             0
#
# =================================================================
# Total params: 75,906
# Trainable params: 75,906
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_62"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_81 (InputLayer)       [(None, 55, 35, 1)]       0
#
#  model_60 (Functional)       (None, 55, 35, 1)         296129
#
#  model_61 (Functional)       (None, 15, 2)             75906
#
# =================================================================
# Total params: 372,035
# Trainable params: 372,035
# Non-trainable params: 0
# _________________________________________________________________
# Epoch: 0, [Real Discriminator :: Loss: 2.114875078201294], [ GAN :: Loss: [1.52587982e+03 1.52578448e+03 9.53797922e-02]]
# Epoch: 0, [Real Discriminator :: Loss: 0.003758322913199663], [ GAN :: Loss: [1.39938489e+03 1.39929114e+03 9.37600136e-02]]
# Epoch: 0, [Real Discriminator :: Loss: 0.0021023249719291925], [ GAN :: Loss: [1.87636365e+03 1.87626978e+03 9.38402154e-02]]
# Epoch: 0, [Real Discriminator :: Loss: 0.0018364278366789222], [ GAN :: Loss: [1.42095984e+03 1.42086597e+03 9.39047784e-02]]
# Epoch: 0, [Real Discriminator :: Loss: 0.0024854333605617285], [ GAN :: Loss: [1.51159167e+03 1.51149768e+03 9.39945541e-02]]
# Epoch: 0, [Real Discriminator :: Loss: 0.0019127089763060212], [ GAN :: Loss: [1.10617621e+03 1.10608234e+03 9.38929170e-02]]
# Epoch: 0, [Real Discriminator :: Loss: 0.0018628527177497745], [ GAN :: Loss: [1.22718115e+03 1.22708984e+03 9.12632160e-02]]
# Epoch: 0, [Real Discriminator :: Loss: 0.001618460868485272], [ GAN :: Loss: [1.03319647e+03 1.03310516e+03 9.12843011e-02]]
# Epoch: 0, [Real Discriminator :: Loss: 0.0016794088296592236], [ GAN :: Loss: [1.51642731e+03 1.51633588e+03 9.13987234e-02]]
# Epoch: 0, [Real Discriminator :: Loss: 0.0020641505252569914], [ GAN :: Loss: [1.31071289e+03 1.31062134e+03 9.15180184e-02]]
# Epoch: 0, [Real Discriminator :: Loss: 0.002110494067892432], [ GAN :: Loss: [1.35878723e+03 1.35869556e+03 9.16270241e-02]]
# Epoch: 0, [Real Discriminator :: Loss: 0.002754359506070614], [ GAN :: Loss: [1.25306342e+03 1.25297168e+03 9.17402320e-02]]
# Epoch: 0, [Real Discriminator :: Loss: 0.0025090298149734735], [ GAN :: Loss: [1.45725012e+03 1.45715833e+03 9.18478593e-02]]
# Epoch: 0, [Real Discriminator :: Loss: 0.0029458499047905207], [ GAN :: Loss: [1.28489612e+03 1.28480420e+03 9.19549428e-02]]
# Epoch: 0, [Real Discriminator :: Loss: 0.0023468560539186], [ GAN :: Loss: [1.44906567e+03 1.44897363e+03 9.20624174e-02]]
# Epoch: 0, [Real Discriminator :: Loss: 0.0024362157564610243], [ GAN :: Loss: [1.24769904e+03 1.24760687e+03 9.21752788e-02]]
# Epoch: 1, [Real Discriminator :: Loss: 0.0025719378609210253], [ GAN :: Loss: [1.37313721e+03 1.37304492e+03 9.22859199e-02]]
# Epoch: 1, [Real Discriminator :: Loss: 0.002836699364706874], [ GAN :: Loss: [1.78163354e+03 1.78154114e+03 9.23940092e-02]]
# Epoch: 1, [Real Discriminator :: Loss: 0.0020658925641328096], [ GAN :: Loss: [1.71938647e+03 1.71929395e+03 9.25045088e-02]]
# Epoch: 1, [Real Discriminator :: Loss: 0.0027785422280430794], [ GAN :: Loss: [1.47076416e+03 1.47067151e+03 9.26146470e-02]]
# Epoch: 1, [Real Discriminator :: Loss: 0.0022856134455651045], [ GAN :: Loss: [1.21693854e+03 1.21684576e+03 9.27246623e-02]]
# Epoch: 1, [Real Discriminator :: Loss: 0.0021747818682342768], [ GAN :: Loss: [1.53350116e+03 1.53340833e+03 9.28356200e-02]]
# Epoch: 1, [Real Discriminator :: Loss: 0.003200377570465207], [ GAN :: Loss: [1.21432434e+03 1.21423145e+03 9.29485075e-02]]
# Epoch: 1, [Real Discriminator :: Loss: 0.0022679737303406], [ GAN :: Loss: [1.09129053e+03 1.09119751e+03 9.30433907e-02]]
# Epoch: 1, [Real Discriminator :: Loss: 0.002242690185084939], [ GAN :: Loss: [1.52648755e+03 1.52639441e+03 9.31531303e-02]]
# Epoch: 1, [Real Discriminator :: Loss: 0.003126101801171899], [ GAN :: Loss: [1.57720483e+03 1.57711157e+03 9.32608582e-02]]
# Epoch: 1, [Real Discriminator :: Loss: 0.0030950717628002167], [ GAN :: Loss: [1.34913330e+03 1.34903992e+03 9.33613181e-02]]
# Epoch: 1, [Real Discriminator :: Loss: 0.002722949953749776], [ GAN :: Loss: [1.73982507e+03 1.73973157e+03 9.34661813e-02]]
# Epoch: 1, [Real Discriminator :: Loss: 0.0025217910297214985], [ GAN :: Loss: [1.21573041e+03 1.21563684e+03 9.35727544e-02]]
# Epoch: 1, [Real Discriminator :: Loss: 0.0034086816012859344], [ GAN :: Loss: [1.28505334e+03 1.28495972e+03 9.36781093e-02]]
# Epoch: 1, [Real Discriminator :: Loss: 0.002557862550020218], [ GAN :: Loss: [1.31005457e+03 1.30996082e+03 9.37777571e-02]]
# Epoch: 1, [Real Discriminator :: Loss: 0.002150719752535224], [ GAN :: Loss: [1.65770020e+03 1.65760632e+03 9.38851424e-02]]
# Epoch: 2, [Real Discriminator :: Loss: 0.0028983212541788816], [ GAN :: Loss: [1.26133600e+03 1.26124200e+03 9.39970389e-02]]
# Epoch: 2, [Real Discriminator :: Loss: 0.002913507167249918], [ GAN :: Loss: [1.35287158e+03 1.35277747e+03 9.41004418e-02]]
# Epoch: 2, [Real Discriminator :: Loss: 0.003392730839550495], [ GAN :: Loss: [1.16430725e+03 1.16421301e+03 9.41973105e-02]]
# Epoch: 2, [Real Discriminator :: Loss: 0.002396846655756235], [ GAN :: Loss: [1.33406909e+03 1.33397485e+03 9.42784585e-02]]
# Epoch: 2, [Real Discriminator :: Loss: 0.0021145022474229336], [ GAN :: Loss: [9.15704346e+02 9.15609985e+02 9.43649076e-02]]
# Epoch: 2, [Real Discriminator :: Loss: 0.002160722855478525], [ GAN :: Loss: [1.63371948e+03 1.63362500e+03 9.44461823e-02]]
# Epoch: 2, [Real Discriminator :: Loss: 0.002697895048186183], [ GAN :: Loss: [1.76362842e+03 1.76353394e+03 9.45164226e-02]]
# Epoch: 2, [Real Discriminator :: Loss: 0.002760673640295863], [ GAN :: Loss: [1.19472778e+03 1.19463318e+03 9.45783369e-02]]
# Epoch: 2, [Real Discriminator :: Loss: 0.004551130812615156], [ GAN :: Loss: [1.54085181e+03 1.54075720e+03 9.46421213e-02]]
# Epoch: 2, [Real Discriminator :: Loss: 0.002778308931738138], [ GAN :: Loss: [1.26592505e+03 1.26583032e+03 9.46950503e-02]]
# Epoch: 2, [Real Discriminator :: Loss: 0.002478963229805231], [ GAN :: Loss: [1.10344666e+03 1.10335193e+03 9.47563238e-02]]
# Epoch: 2, [Real Discriminator :: Loss: 0.002301849890500307], [ GAN :: Loss: [1.27322717e+03 1.27313232e+03 9.48224366e-02]]
# Epoch: 2, [Real Discriminator :: Loss: 0.002113861031830311], [ GAN :: Loss: [1.27350647e+03 1.27341162e+03 9.48900878e-02]]
# Epoch: 2, [Real Discriminator :: Loss: 0.0024486726615577936], [ GAN :: Loss: [1.54210889e+03 1.54201392e+03 9.49577168e-02]]
# Epoch: 2, [Real Discriminator :: Loss: 0.002815836574882269], [ GAN :: Loss: [1.39497217e+03 1.39487720e+03 9.50208306e-02]]
# Epoch: 2, [Real Discriminator :: Loss: 0.002414459828287363], [ GAN :: Loss: [1.61894946e+03 1.61885437e+03 9.50815678e-02]]
# Epoch: 3, [Real Discriminator :: Loss: 0.002407386666163802], [ GAN :: Loss: [1.49497021e+03 1.49487512e+03 9.51328985e-02]]
# Epoch: 3, [Real Discriminator :: Loss: 0.0020149401389062405], [ GAN :: Loss: [1.54783801e+03 1.54774280e+03 9.51796770e-02]]
# Epoch: 3, [Real Discriminator :: Loss: 0.0022089246194809675], [ GAN :: Loss: [1.66747241e+03 1.66737720e+03 9.52263102e-02]]
# Epoch: 3, [Real Discriminator :: Loss: 0.003253686474636197], [ GAN :: Loss: [1.68518085e+03 1.68508557e+03 9.52728614e-02]]
# Epoch: 3, [Real Discriminator :: Loss: 0.0025096088647842407], [ GAN :: Loss: [1.33478772e+03 1.33469238e+03 9.53101777e-02]]
# Epoch: 3, [Real Discriminator :: Loss: 0.0029751858673989773], [ GAN :: Loss: [1.26496094e+03 1.26486560e+03 9.53526273e-02]]
# Epoch: 3, [Real Discriminator :: Loss: 0.0021364453714340925], [ GAN :: Loss: [2.10070337e+03 2.10060791e+03 9.53866951e-02]]
# Epoch: 3, [Real Discriminator :: Loss: 0.0026605476159602404], [ GAN :: Loss: [1.23819702e+03 1.23810156e+03 9.54127908e-02]]
# Epoch: 3, [Real Discriminator :: Loss: 0.0021117033902555704], [ GAN :: Loss: [1.21386548e+03 1.21377002e+03 9.54363309e-02]]
# Epoch: 3, [Real Discriminator :: Loss: 0.002613692544400692], [ GAN :: Loss: [1.70679785e+03 1.70670239e+03 9.54618827e-02]]
# Epoch: 3, [Real Discriminator :: Loss: 0.0018765548011288047], [ GAN :: Loss: [1.43680737e+03 1.43671191e+03 9.54797789e-02]]
# Epoch: 3, [Real Discriminator :: Loss: 0.0018851320492103696], [ GAN :: Loss: [1.41824304e+03 1.41814758e+03 9.55005363e-02]]
# Epoch: 3, [Real Discriminator :: Loss: 0.001624229014851153], [ GAN :: Loss: [1.59549475e+03 1.59539917e+03 9.55219716e-02]]
# Epoch: 3, [Real Discriminator :: Loss: 0.0020192929077893496], [ GAN :: Loss: [1.53134070e+03 1.53124512e+03 9.55439433e-02]]
# Epoch: 3, [Real Discriminator :: Loss: 0.002583544934168458], [ GAN :: Loss: [1.49824829e+03 1.49815271e+03 9.55640562e-02]]
# Epoch: 3, [Real Discriminator :: Loss: 0.002615635981783271], [ GAN :: Loss: [1.20669910e+03 1.20660352e+03 9.55818854e-02]]
# Epoch: 4, [Real Discriminator :: Loss: 0.002854771912097931], [ GAN :: Loss: [1.35826111e+03 1.35816553e+03 9.55983326e-02]]
# Epoch: 4, [Real Discriminator :: Loss: 0.004729138687252998], [ GAN :: Loss: [1.87655908e+03 1.87646350e+03 9.56143998e-02]]
# Epoch: 4, [Real Discriminator :: Loss: 0.0021148750092834234], [ GAN :: Loss: [1.40593079e+03 1.40583521e+03 9.56224315e-02]]
# Epoch: 4, [Real Discriminator :: Loss: 0.002389361849054694], [ GAN :: Loss: [1.69019751e+03 1.69010193e+03 9.56360772e-02]]
# Epoch: 4, [Real Discriminator :: Loss: 0.0017743648495525122], [ GAN :: Loss: [1.52763562e+03 1.52753992e+03 9.56491530e-02]]
# Epoch: 4, [Real Discriminator :: Loss: 0.002029803581535816], [ GAN :: Loss: [1.22292175e+03 1.22282605e+03 9.56649035e-02]]
# Epoch: 4, [Real Discriminator :: Loss: 0.0017665342893451452], [ GAN :: Loss: [1.14241907e+03 1.14232336e+03 9.56781916e-02]]
# Epoch: 4, [Real Discriminator :: Loss: 0.0016114132013171911], [ GAN :: Loss: [1.49897168e+03 1.49887598e+03 9.56893004e-02]]
# Epoch: 4, [Real Discriminator :: Loss: 0.0027714876923710108], [ GAN :: Loss: [1.78711047e+03 1.78701477e+03 9.57001261e-02]]
# Epoch: 4, [Real Discriminator :: Loss: 0.0015567558584734797], [ GAN :: Loss: [1.68326001e+03 1.68316431e+03 9.57076959e-02]]
# Epoch: 4, [Real Discriminator :: Loss: 0.0018234894378110766], [ GAN :: Loss: [1.34167688e+03 1.34158118e+03 9.57178399e-02]]
# Epoch: 4, [Real Discriminator :: Loss: 0.002491555642336607], [ GAN :: Loss: [1.15202808e+03 1.15193237e+03 9.57279466e-02]]
# Epoch: 4, [Real Discriminator :: Loss: 0.001394871505908668], [ GAN :: Loss: [1.40707288e+03 1.40697717e+03 9.57357064e-02]]
# Epoch: 4, [Real Discriminator :: Loss: 0.0017713999841362238], [ GAN :: Loss: [1.46701453e+03 1.46691882e+03 9.57465917e-02]]
# Epoch: 4, [Real Discriminator :: Loss: 0.0014819210628047585], [ GAN :: Loss: [1.42712012e+03 1.42702441e+03 9.57559235e-02]]
# Epoch: 4, [Real Discriminator :: Loss: 0.0016088372794911265], [ GAN :: Loss: [1.52763574e+03 1.52753992e+03 9.57660004e-02]]
# Epoch: 5, [Real Discriminator :: Loss: 0.0019958578050136566], [ GAN :: Loss: [1.76842932e+03 1.76833350e+03 9.57757756e-02]]
# Epoch: 5, [Real Discriminator :: Loss: 0.0015841114800423384], [ GAN :: Loss: [1.64013135e+03 1.64003552e+03 9.57842954e-02]]
# Epoch: 5, [Real Discriminator :: Loss: 0.0016636417713016272], [ GAN :: Loss: [1.59157495e+03 1.59147913e+03 9.57938768e-02]]
# Epoch: 5, [Real Discriminator :: Loss: 0.0016966575058177114], [ GAN :: Loss: [1.73362292e+03 1.73352710e+03 9.58030187e-02]]
# Epoch: 5, [Real Discriminator :: Loss: 0.001274498412385583], [ GAN :: Loss: [1.34674255e+03 1.34664673e+03 9.58104953e-02]]
# Epoch: 5, [Real Discriminator :: Loss: 0.0017008600989356637], [ GAN :: Loss: [1.32171265e+03 1.32161682e+03 9.58168730e-02]]
# Epoch: 5, [Real Discriminator :: Loss: 0.002635437063872814], [ GAN :: Loss: [1.40318896e+03 1.40309314e+03 9.58220139e-02]]
# Epoch: 5, [Real Discriminator :: Loss: 0.0025848806835711002], [ GAN :: Loss: [1.52832617e+03 1.52823035e+03 9.58255604e-02]]
# Epoch: 5, [Real Discriminator :: Loss: 0.0014980077976360917], [ GAN :: Loss: [1.09777795e+03 1.09768213e+03 9.58289690e-02]]
# Epoch: 5, [Real Discriminator :: Loss: 0.0015836432576179504], [ GAN :: Loss: [1.35948145e+03 1.35938562e+03 9.58316475e-02]]
# Epoch: 5, [Real Discriminator :: Loss: 0.0012736415956169367], [ GAN :: Loss: [1.81257019e+03 1.81247437e+03 9.58340727e-02]]
# Epoch: 5, [Real Discriminator :: Loss: 0.0016045758966356516], [ GAN :: Loss: [1.73571423e+03 1.73561841e+03 9.58371796e-02]]
# Epoch: 5, [Real Discriminator :: Loss: 0.00160702015273273], [ GAN :: Loss: [1.39243103e+03 1.39233521e+03 9.58396606e-02]]
# Epoch: 5, [Real Discriminator :: Loss: 0.001839909004047513], [ GAN :: Loss: [1.45933301e+03 1.45923718e+03 9.58425142e-02]]
# Epoch: 5, [Real Discriminator :: Loss: 0.001062476309016347], [ GAN :: Loss: [1.83934900e+03 1.83925317e+03 9.58446711e-02]]
# Epoch: 5, [Real Discriminator :: Loss: 0.001161940861493349], [ GAN :: Loss: [1.31897583e+03 1.31888000e+03 9.58485492e-02]]
# Epoch: 6, [Real Discriminator :: Loss: 0.0015601774211972952], [ GAN :: Loss: [1.76957336e+03 1.76947754e+03 9.58522074e-02]]
# Epoch: 6, [Real Discriminator :: Loss: 0.0011873317416757345], [ GAN :: Loss: [1.29170654e+03 1.29161072e+03 9.58545990e-02]]
# Epoch: 6, [Real Discriminator :: Loss: 0.0011910562170669436], [ GAN :: Loss: [1.32574097e+03 1.32564514e+03 9.58580561e-02]]
# Epoch: 6, [Real Discriminator :: Loss: 0.0014038820518180728], [ GAN :: Loss: [1.47511340e+03 1.47501758e+03 9.58613865e-02]]
# Epoch: 6, [Real Discriminator :: Loss: 0.0023072927724570036], [ GAN :: Loss: [1.34699060e+03 1.34689478e+03 9.58638489e-02]]
# Epoch: 6, [Real Discriminator :: Loss: 0.0015426207100972533], [ GAN :: Loss: [1.18694617e+03 1.18685034e+03 9.58647840e-02]]
# Epoch: 6, [Real Discriminator :: Loss: 0.0016194912604987621], [ GAN :: Loss: [1.41123181e+03 1.41113599e+03 9.58674811e-02]]
# Epoch: 6, [Real Discriminator :: Loss: 0.0018560257740318775], [ GAN :: Loss: [1.60907214e+03 1.60897632e+03 9.58702452e-02]]
# Epoch: 6, [Real Discriminator :: Loss: 0.0013950392603874207], [ GAN :: Loss: [1.41794263e+03 1.41784680e+03 9.58717018e-02]]
# Epoch: 6, [Real Discriminator :: Loss: 0.0010281490394845605], [ GAN :: Loss: [1.31003857e+03 1.30994275e+03 9.58749838e-02]]
# Epoch: 6, [Real Discriminator :: Loss: 0.0010210821637883782], [ GAN :: Loss: [1.37014221e+03 1.37004639e+03 9.58785787e-02]]
# Epoch: 6, [Real Discriminator :: Loss: 0.0011991678038612008], [ GAN :: Loss: [1.63261340e+03 1.63251758e+03 9.58826989e-02]]
# Epoch: 6, [Real Discriminator :: Loss: 0.0012039404828101397], [ GAN :: Loss: [1.63375983e+03 1.63366394e+03 9.58864279e-02]]
# Epoch: 6, [Real Discriminator :: Loss: 0.0015836232341825962], [ GAN :: Loss: [1.23467957e+03 1.23458362e+03 9.58902203e-02]]
# Epoch: 6, [Real Discriminator :: Loss: 0.0014096579980105162], [ GAN :: Loss: [1.04993396e+03 1.04983801e+03 9.58927423e-02]]
# Epoch: 6, [Real Discriminator :: Loss: 0.001567367697134614], [ GAN :: Loss: [1.35632520e+03 1.35622925e+03 9.58961062e-02]]
# Epoch: 7, [Real Discriminator :: Loss: 0.0016936289612203836], [ GAN :: Loss: [1.70179431e+03 1.70169836e+03 9.58989412e-02]]
# Epoch: 7, [Real Discriminator :: Loss: 0.0011914814822375774], [ GAN :: Loss: [1.13111267e+03 1.13101672e+03 9.58990976e-02]]
# Epoch: 7, [Real Discriminator :: Loss: 0.0015150520484894514], [ GAN :: Loss: [1.39779626e+03 1.39770032e+03 9.59016830e-02]]
# Epoch: 7, [Real Discriminator :: Loss: 0.0014164113672450185], [ GAN :: Loss: [1.30155872e+03 1.30146277e+03 9.59045216e-02]]
# Epoch: 7, [Real Discriminator :: Loss: 0.0012330833123996854], [ GAN :: Loss: [1.37659155e+03 1.37649561e+03 9.59063098e-02]]
# Epoch: 7, [Real Discriminator :: Loss: 0.0010051444405689836], [ GAN :: Loss: [1.41410107e+03 1.41400513e+03 9.59080756e-02]]
# Epoch: 7, [Real Discriminator :: Loss: 0.0009161293273791671], [ GAN :: Loss: [1.53626672e+03 1.53617078e+03 9.59100313e-02]]
# Epoch: 7, [Real Discriminator :: Loss: 0.001212108414620161], [ GAN :: Loss: [1.15749988e+03 1.15740393e+03 9.59121175e-02]]
# Epoch: 7, [Real Discriminator :: Loss: 0.0009735478670336306], [ GAN :: Loss: [1.64563196e+03 1.64553601e+03 9.59137455e-02]]
# Epoch: 7, [Real Discriminator :: Loss: 0.0015881540020927787], [ GAN :: Loss: [1.45395557e+03 1.45385962e+03 9.59158503e-02]]
# Epoch: 7, [Real Discriminator :: Loss: 0.0016458769096061587], [ GAN :: Loss: [1.54989197e+03 1.54979602e+03 9.59172435e-02]]
# Epoch: 7, [Real Discriminator :: Loss: 0.0010389654198661447], [ GAN :: Loss: [1.29267871e+03 1.29258276e+03 9.59179252e-02]]
# Epoch: 7, [Real Discriminator :: Loss: 0.0008930257754400373], [ GAN :: Loss: [1.55955505e+03 1.55945911e+03 9.59188491e-02]]
# Epoch: 7, [Real Discriminator :: Loss: 0.0008432288304902613], [ GAN :: Loss: [1.23793677e+03 1.23784082e+03 9.59199034e-02]]
# Epoch: 7, [Real Discriminator :: Loss: 0.0011137268738821149], [ GAN :: Loss: [1.23303394e+03 1.23293799e+03 9.59204100e-02]]
# Epoch: 7, [Real Discriminator :: Loss: 0.0015896399272605777], [ GAN :: Loss: [1.15689587e+03 1.15679993e+03 9.59207788e-02]]
# Epoch: 8, [Real Discriminator :: Loss: 0.0013574870536103845], [ GAN :: Loss: [1.29088794e+03 1.29079199e+03 9.59207937e-02]]
# Epoch: 8, [Real Discriminator :: Loss: 0.0010585826821625233], [ GAN :: Loss: [1.50106555e+03 1.50096960e+03 9.59219038e-02]]
# Epoch: 8, [Real Discriminator :: Loss: 0.0008558070403523743], [ GAN :: Loss: [1.90164233e+03 1.90154639e+03 9.59222727e-02]]
# Epoch: 8, [Real Discriminator :: Loss: 0.000881713000126183], [ GAN :: Loss: [1.38297351e+03 1.38287756e+03 9.59225968e-02]]
# Epoch: 8, [Real Discriminator :: Loss: 0.0010730057256296277], [ GAN :: Loss: [1.34966309e+03 1.34956714e+03 9.59229842e-02]]
# Epoch: 8, [Real Discriminator :: Loss: 0.0010392977856099606], [ GAN :: Loss: [1.62738989e+03 1.62729395e+03 9.59239602e-02]]
# Epoch: 8, [Real Discriminator :: Loss: 0.0007273536175489426], [ GAN :: Loss: [1.65041431e+03 1.65031836e+03 9.59242806e-02]]
# Epoch: 8, [Real Discriminator :: Loss: 0.0008071648189797997], [ GAN :: Loss: [1.40409949e+03 1.40400354e+03 9.59247313e-02]]
# Epoch: 8, [Real Discriminator :: Loss: 0.000835946062579751], [ GAN :: Loss: [1.57137952e+03 1.57128357e+03 9.59251150e-02]]
# Epoch: 8, [Real Discriminator :: Loss: 0.0011322196805849671], [ GAN :: Loss: [1.51149146e+03 1.51139551e+03 9.59256031e-02]]
# Epoch: 8, [Real Discriminator :: Loss: 0.0015968818916007876], [ GAN :: Loss: [1.26636353e+03 1.26626758e+03 9.59264413e-02]]
# Epoch: 8, [Real Discriminator :: Loss: 0.0008500592084601521], [ GAN :: Loss: [1.17153992e+03 1.17144397e+03 9.59260389e-02]]
# Epoch: 8, [Real Discriminator :: Loss: 0.0008158107521012425], [ GAN :: Loss: [1.34432788e+03 1.34423193e+03 9.59264562e-02]]
# Epoch: 8, [Real Discriminator :: Loss: 0.0012611506972461939], [ GAN :: Loss: [1.19905029e+03 1.19895435e+03 9.59267095e-02]]
# Epoch: 8, [Real Discriminator :: Loss: 0.0008573257946409285], [ GAN :: Loss: [1.30772266e+03 1.30762671e+03 9.59270000e-02]]
# Epoch: 8, [Real Discriminator :: Loss: 0.001639524707570672], [ GAN :: Loss: [1.62815234e+03 1.62805640e+03 9.59274508e-02]]
# Epoch: 9, [Real Discriminator :: Loss: 0.000923263025470078], [ GAN :: Loss: [1.44551147e+03 1.44541553e+03 9.59280618e-02]]
# Epoch: 9, [Real Discriminator :: Loss: 0.0008208032813854516], [ GAN :: Loss: [1.48472192e+03 1.48462598e+03 9.59284566e-02]]
# Epoch: 9, [Real Discriminator :: Loss: 0.0007579993107356131], [ GAN :: Loss: [1.46161670e+03 1.46152075e+03 9.59287398e-02]]
# Epoch: 9, [Real Discriminator :: Loss: 0.000846533162984997], [ GAN :: Loss: [1.41012549e+03 1.41002954e+03 9.59292054e-02]]
# Epoch: 9, [Real Discriminator :: Loss: 0.0010953802848234773], [ GAN :: Loss: [1.01096283e+03 1.01086688e+03 9.59302932e-02]]
# Epoch: 9, [Real Discriminator :: Loss: 0.0008388946298509836], [ GAN :: Loss: [1.46390430e+03 1.46380835e+03 9.59302895e-02]]
# Epoch: 9, [Real Discriminator :: Loss: 0.0007436306914314628], [ GAN :: Loss: [1.37930066e+03 1.37920471e+03 9.59307216e-02]]
# Epoch: 9, [Real Discriminator :: Loss: 0.0006136915762908757], [ GAN :: Loss: [1.44809631e+03 1.44800037e+03 9.59319510e-02]]
# Epoch: 9, [Real Discriminator :: Loss: 0.0008619287982583046], [ GAN :: Loss: [1.40928027e+03 1.40918433e+03 9.59325619e-02]]
# Epoch: 9, [Real Discriminator :: Loss: 0.0007197482627816498], [ GAN :: Loss: [1.11787402e+03 1.11777808e+03 9.59329084e-02]]
# Epoch: 9, [Real Discriminator :: Loss: 0.0008209517691284418], [ GAN :: Loss: [1.10344775e+03 1.10335181e+03 9.59334150e-02]]
# Epoch: 9, [Real Discriminator :: Loss: 0.0006897668936289847], [ GAN :: Loss: [1.59074756e+03 1.59065161e+03 9.59338918e-02]]
# Epoch: 9, [Real Discriminator :: Loss: 0.0008709740359336138], [ GAN :: Loss: [1.26431628e+03 1.26422034e+03 9.59343761e-02]]
# Epoch: 9, [Real Discriminator :: Loss: 0.0009866945911198854], [ GAN :: Loss: [1.78777795e+03 1.78768201e+03 9.59349051e-02]]
# Epoch: 9, [Real Discriminator :: Loss: 0.0007740798755548894], [ GAN :: Loss: [1.48365710e+03 1.48356116e+03 9.59351137e-02]]
# Epoch: 9, [Real Discriminator :: Loss: 0.0010172814363613725], [ GAN :: Loss: [1.59650354e+03 1.59640759e+03 9.59363282e-02]]
# Epoch: 10, [Real Discriminator :: Loss: 0.0007387340883724391], [ GAN :: Loss: [1.47463989e+03 1.47454395e+03 9.59365889e-02]]
# Epoch: 10, [Real Discriminator :: Loss: 0.0027084588073194027], [ GAN :: Loss: [1.10703125e+03 1.10693530e+03 9.59370993e-02]]
# Epoch: 10, [Real Discriminator :: Loss: 0.0031160437501966953], [ GAN :: Loss: [1.88425830e+03 1.88416235e+03 9.59377326e-02]]
# Epoch: 10, [Real Discriminator :: Loss: 0.0009723806288093328], [ GAN :: Loss: [1.34539270e+03 1.34529675e+03 9.59379412e-02]]
# Epoch: 10, [Real Discriminator :: Loss: 0.000846083159558475], [ GAN :: Loss: [1.57516431e+03 1.57506836e+03 9.59383324e-02]]
# Epoch: 10, [Real Discriminator :: Loss: 0.0008668243535794318], [ GAN :: Loss: [1.03327789e+03 1.03318195e+03 9.59389880e-02]]
# Epoch: 10, [Real Discriminator :: Loss: 0.0008566700271330774], [ GAN :: Loss: [1.69707556e+03 1.69697961e+03 9.59399715e-02]]
# Epoch: 10, [Real Discriminator :: Loss: 0.0009372306521981955], [ GAN :: Loss: [1.25664795e+03 1.25655200e+03 9.59405005e-02]]
# Epoch: 10, [Real Discriminator :: Loss: 0.0005745549569837749], [ GAN :: Loss: [1.55514429e+03 1.55504834e+03 9.59407799e-02]]
# Epoch: 10, [Real Discriminator :: Loss: 0.000562019064091146], [ GAN :: Loss: [1.27002673e+03 1.26993079e+03 9.59410779e-02]]
# Epoch: 10, [Real Discriminator :: Loss: 0.0005813210154883564], [ GAN :: Loss: [1.25200867e+03 1.25191272e+03 9.59416218e-02]]
# Epoch: 10, [Real Discriminator :: Loss: 0.0013719437411054969], [ GAN :: Loss: [1.18658630e+03 1.18649036e+03 9.59422849e-02]]
# Epoch: 10, [Real Discriminator :: Loss: 0.0009016951080411673], [ GAN :: Loss: [1.47861707e+03 1.47852112e+03 9.59430486e-02]]
# Epoch: 10, [Real Discriminator :: Loss: 0.0007749420474283397], [ GAN :: Loss: [1.50795349e+03 1.50785754e+03 9.59435217e-02]]
# Epoch: 10, [Real Discriminator :: Loss: 0.0006128524546511471], [ GAN :: Loss: [1.95776428e+03 1.95766833e+03 9.59441140e-02]]
# Epoch: 10, [Real Discriminator :: Loss: 0.0008180075092241168], [ GAN :: Loss: [1.42578711e+03 1.42569116e+03 9.59447548e-02]]
# Epoch: 11, [Real Discriminator :: Loss: 0.0006476546986959875], [ GAN :: Loss: [1.50236035e+03 1.50226440e+03 9.59452465e-02]]
# Epoch: 11, [Real Discriminator :: Loss: 0.0008465678547509015], [ GAN :: Loss: [1.39961865e+03 1.39952271e+03 9.59459469e-02]]
# Epoch: 11, [Real Discriminator :: Loss: 0.0005834846524521708], [ GAN :: Loss: [2.05149072e+03 2.05139478e+03 9.59462561e-02]]
# Epoch: 11, [Real Discriminator :: Loss: 0.0010447934037074447], [ GAN :: Loss: [1.72323352e+03 1.72313757e+03 9.59466659e-02]]
# Epoch: 11, [Real Discriminator :: Loss: 0.0006491360836662352], [ GAN :: Loss: [1.11410034e+03 1.11400439e+03 9.59470011e-02]]
# Epoch: 11, [Real Discriminator :: Loss: 0.0005643960903398693], [ GAN :: Loss: [1.36473669e+03 1.36464075e+03 9.59473811e-02]]
# Epoch: 11, [Real Discriminator :: Loss: 0.0006124952342361212], [ GAN :: Loss: [1.50256555e+03 1.50246960e+03 9.59478021e-02]]
# Epoch: 11, [Real Discriminator :: Loss: 0.0008444037521257997], [ GAN :: Loss: [1.06203967e+03 1.06194373e+03 9.59484056e-02]]
# Epoch: 11, [Real Discriminator :: Loss: 0.00046641711378470063], [ GAN :: Loss: [1.65129236e+03 1.65119641e+03 9.59488191e-02]]
# Epoch: 11, [Real Discriminator :: Loss: 0.0006966572836972773], [ GAN :: Loss: [1.46423596e+03 1.46414001e+03 9.59495455e-02]]
# Epoch: 11, [Real Discriminator :: Loss: 0.0006356000085361302], [ GAN :: Loss: [1.31722351e+03 1.31712756e+03 9.59500261e-02]]
# Epoch: 11, [Real Discriminator :: Loss: 0.0006319750100374222], [ GAN :: Loss: [1.64150232e+03 1.64140637e+03 9.59505923e-02]]
# Epoch: 11, [Real Discriminator :: Loss: 0.0005414972547441721], [ GAN :: Loss: [1.68862305e+03 1.68852710e+03 9.59512740e-02]]
# Epoch: 11, [Real Discriminator :: Loss: 0.0005801940569654107], [ GAN :: Loss: [1.54616992e+03 1.54607397e+03 9.59519744e-02]]
# Epoch: 11, [Real Discriminator :: Loss: 0.0013158984947949648], [ GAN :: Loss: [1.23173914e+03 1.23164319e+03 9.59525444e-02]]
# Epoch: 11, [Real Discriminator :: Loss: 0.0010714688105508685], [ GAN :: Loss: [1.66161792e+03 1.66152197e+03 9.59528089e-02]]
# Epoch: 12, [Real Discriminator :: Loss: 0.0012769948225468397], [ GAN :: Loss: [1.23481714e+03 1.23472119e+03 9.59540009e-02]]
# Epoch: 12, [Real Discriminator :: Loss: 0.0007357308641076088], [ GAN :: Loss: [1.27815796e+03 1.27806201e+03 9.59543586e-02]]
# Epoch: 12, [Real Discriminator :: Loss: 0.0006357452948577702], [ GAN :: Loss: [1.40769592e+03 1.40759998e+03 9.59548503e-02]]
# Epoch: 12, [Real Discriminator :: Loss: 0.000841582368593663], [ GAN :: Loss: [1.22369067e+03 1.22359473e+03 9.59555469e-02]]
# Epoch: 12, [Real Discriminator :: Loss: 0.0004139374941587448], [ GAN :: Loss: [1.30572107e+03 1.30562512e+03 9.59560797e-02]]
# Epoch: 12, [Real Discriminator :: Loss: 0.0005846952553838491], [ GAN :: Loss: [1.60745947e+03 1.60736353e+03 9.59567539e-02]]
# Epoch: 12, [Real Discriminator :: Loss: 0.0004240301204845309], [ GAN :: Loss: [9.73235901e+02 9.73139954e+02 9.59574468e-02]]
# Epoch: 12, [Real Discriminator :: Loss: 0.000724752782844007], [ GAN :: Loss: [1.37762427e+03 1.37752832e+03 9.59581472e-02]]
# Epoch: 12, [Real Discriminator :: Loss: 0.0007918401970528066], [ GAN :: Loss: [1.22031592e+03 1.22021997e+03 9.59587060e-02]]
# Epoch: 12, [Real Discriminator :: Loss: 0.0005034697824157774], [ GAN :: Loss: [1.74192871e+03 1.74183276e+03 9.59590822e-02]]
# Epoch: 12, [Real Discriminator :: Loss: 0.0009221608634106815], [ GAN :: Loss: [1.32379675e+03 1.32370081e+03 9.59597491e-02]]
# Epoch: 12, [Real Discriminator :: Loss: 0.0006268860306590796], [ GAN :: Loss: [1.07799316e+03 1.07789722e+03 9.59598087e-02]]
# Epoch: 12, [Real Discriminator :: Loss: 0.0004150208842474967], [ GAN :: Loss: [1.73120630e+03 1.73111035e+03 9.59603786e-02]]
# Epoch: 12, [Real Discriminator :: Loss: 0.0007815110730007291], [ GAN :: Loss: [1.16325916e+03 1.16316321e+03 9.59611088e-02]]
# Epoch: 12, [Real Discriminator :: Loss: 0.0004014584410469979], [ GAN :: Loss: [1.28140234e+03 1.28130640e+03 9.59615856e-02]]
# Epoch: 12, [Real Discriminator :: Loss: 0.0006958814919926226], [ GAN :: Loss: [1.66518506e+03 1.66508911e+03 9.59622934e-02]]
# Epoch: 13, [Real Discriminator :: Loss: 0.0005595574039034545], [ GAN :: Loss: [1.16910632e+03 1.16901038e+03 9.59628336e-02]]
# Epoch: 13, [Real Discriminator :: Loss: 0.00042255452717654407], [ GAN :: Loss: [1.63331433e+03 1.63321838e+03 9.59633738e-02]]
# Epoch: 13, [Real Discriminator :: Loss: 0.0009406228782609105], [ GAN :: Loss: [1.67920911e+03 1.67911316e+03 9.59640816e-02]]
# Epoch: 13, [Real Discriminator :: Loss: 0.00033424218418076634], [ GAN :: Loss: [1.36030872e+03 1.36021277e+03 9.59647000e-02]]
# Epoch: 13, [Real Discriminator :: Loss: 0.0018471506191417575], [ GAN :: Loss: [1.81297754e+03 1.81288159e+03 9.59655009e-02]]
# Epoch: 13, [Real Discriminator :: Loss: 0.00040997593896463513], [ GAN :: Loss: [1.27629871e+03 1.27620276e+03 9.59659070e-02]]
# Epoch: 13, [Real Discriminator :: Loss: 0.00043690347229130566], [ GAN :: Loss: [1.28919189e+03 1.28909595e+03 9.59665701e-02]]
# Epoch: 13, [Real Discriminator :: Loss: 0.0007547765853814781], [ GAN :: Loss: [1.39355005e+03 1.39345410e+03 9.59673189e-02]]
# Epoch: 13, [Real Discriminator :: Loss: 0.00031082521309144795], [ GAN :: Loss: [1.22657507e+03 1.22647913e+03 9.59679261e-02]]
# Epoch: 13, [Real Discriminator :: Loss: 0.000494271342176944], [ GAN :: Loss: [1.28279675e+03 1.28270081e+03 9.59686935e-02]]
# Epoch: 13, [Real Discriminator :: Loss: 0.0007912388537079096], [ GAN :: Loss: [1.40879395e+03 1.40869800e+03 9.59693864e-02]]
# Epoch: 13, [Real Discriminator :: Loss: 0.0004610266478266567], [ GAN :: Loss: [1.09572498e+03 1.09562903e+03 9.59700048e-02]]
# Epoch: 13, [Real Discriminator :: Loss: 0.0012393741635605693], [ GAN :: Loss: [1.34641870e+03 1.34632275e+03 9.59706977e-02]]
# Epoch: 13, [Real Discriminator :: Loss: 0.0003892321255989373], [ GAN :: Loss: [1.27821545e+03 1.27811951e+03 9.59702544e-02]]
# Epoch: 13, [Real Discriminator :: Loss: 0.000461226882180199], [ GAN :: Loss: [1.97491394e+03 1.97481799e+03 9.59710404e-02]]
# Epoch: 13, [Real Discriminator :: Loss: 0.0005223517073318362], [ GAN :: Loss: [2.07314722e+03 2.07305127e+03 9.59717333e-02]]
# Epoch: 14, [Real Discriminator :: Loss: 0.0006214224849827588], [ GAN :: Loss: [1.37390234e+03 1.37380640e+03 9.59723666e-02]]
# Epoch: 14, [Real Discriminator :: Loss: 0.0004098660429008305], [ GAN :: Loss: [1.37315710e+03 1.37306116e+03 9.59730260e-02]]
# Epoch: 14, [Real Discriminator :: Loss: 0.0008622586610727012], [ GAN :: Loss: [1.39463147e+03 1.39453552e+03 9.59737189e-02]]
# Epoch: 14, [Real Discriminator :: Loss: 0.00030411293846555054], [ GAN :: Loss: [1.32281628e+03 1.32272034e+03 9.59743410e-02]]
# Epoch: 14, [Real Discriminator :: Loss: 0.000434081070125103], [ GAN :: Loss: [1.49375476e+03 1.49365881e+03 9.59751233e-02]]
# Epoch: 14, [Real Discriminator :: Loss: 0.0006467567291110754], [ GAN :: Loss: [1.61167871e+03 1.61158276e+03 9.59758610e-02]]
# Epoch: 14, [Real Discriminator :: Loss: 0.000560852640774101], [ GAN :: Loss: [1.45297388e+03 1.45287793e+03 9.59763713e-02]]
# Epoch: 14, [Real Discriminator :: Loss: 0.0006670496077276766], [ GAN :: Loss: [1.70735754e+03 1.70726160e+03 9.59770903e-02]]
# Epoch: 14, [Real Discriminator :: Loss: 0.0005131172365508974], [ GAN :: Loss: [1.49716077e+03 1.49706482e+03 9.59777050e-02]]
# Epoch: 14, [Real Discriminator :: Loss: 0.000485824013594538], [ GAN :: Loss: [1.46505066e+03 1.46495471e+03 9.59783681e-02]]
# Epoch: 14, [Real Discriminator :: Loss: 0.0006566270021721721], [ GAN :: Loss: [1.66192468e+03 1.66182874e+03 9.59791206e-02]]
# Epoch: 14, [Real Discriminator :: Loss: 0.0003928820078726858], [ GAN :: Loss: [1.54051636e+03 1.54042041e+03 9.59797502e-02]]
# Epoch: 14, [Real Discriminator :: Loss: 0.0009586532833054662], [ GAN :: Loss: [1.65543274e+03 1.65533679e+03 9.59805809e-02]]
# Epoch: 14, [Real Discriminator :: Loss: 0.0004988768487237394], [ GAN :: Loss: [1.27642786e+03 1.27633191e+03 9.59810428e-02]]
# Epoch: 14, [Real Discriminator :: Loss: 0.0004902265500277281], [ GAN :: Loss: [1.35409106e+03 1.35399512e+03 9.59818028e-02]]
# Epoch: 14, [Real Discriminator :: Loss: 0.0009406093158759177], [ GAN :: Loss: [1.72617712e+03 1.72608118e+03 9.59824733e-02]]
# Epoch: 15, [Real Discriminator :: Loss: 0.0003656820335891098], [ GAN :: Loss: [1.49340393e+03 1.49330798e+03 9.59828570e-02]]
# Epoch: 15, [Real Discriminator :: Loss: 0.00033245363738387823], [ GAN :: Loss: [1.49387317e+03 1.49377722e+03 9.59836915e-02]]
# Epoch: 15, [Real Discriminator :: Loss: 0.0006508464575745165], [ GAN :: Loss: [1.59673389e+03 1.59663794e+03 9.59845036e-02]]
# Epoch: 15, [Real Discriminator :: Loss: 0.0003332133637741208], [ GAN :: Loss: [1.79612549e+03 1.79602954e+03 9.59852450e-02]]
# Epoch: 15, [Real Discriminator :: Loss: 0.00036126154009252787], [ GAN :: Loss: [1.50060156e+03 1.50050562e+03 9.59859118e-02]]
# Epoch: 15, [Real Discriminator :: Loss: 0.0007579795783385634], [ GAN :: Loss: [1.56027515e+03 1.56017920e+03 9.59866419e-02]]
# Epoch: 15, [Real Discriminator :: Loss: 0.00036997752613388], [ GAN :: Loss: [1.75686548e+03 1.75676953e+03 9.59866419e-02]]
# Epoch: 15, [Real Discriminator :: Loss: 0.0012670957949012518], [ GAN :: Loss: [1.40821228e+03 1.40811633e+03 9.59873497e-02]]
# Epoch: 15, [Real Discriminator :: Loss: 0.0005135913961566985], [ GAN :: Loss: [1.61631311e+03 1.61621716e+03 9.59878638e-02]]
# Epoch: 15, [Real Discriminator :: Loss: 0.000517581996973604], [ GAN :: Loss: [1.50263586e+03 1.50253992e+03 9.59885232e-02]]
# Epoch: 15, [Real Discriminator :: Loss: 0.00037572410656139255], [ GAN :: Loss: [1.45322986e+03 1.45313391e+03 9.59892869e-02]]
# Epoch: 15, [Real Discriminator :: Loss: 0.0005494119832292199], [ GAN :: Loss: [2.01409753e+03 2.01400159e+03 9.59900096e-02]]
# Epoch: 15, [Real Discriminator :: Loss: 0.00048583419993519783], [ GAN :: Loss: [1.60319751e+03 1.60310156e+03 9.59907174e-02]]
# Epoch: 15, [Real Discriminator :: Loss: 0.00031988180126063526], [ GAN :: Loss: [1.64118787e+03 1.64109192e+03 9.59912278e-02]]
# Epoch: 15, [Real Discriminator :: Loss: 0.0006351054180413485], [ GAN :: Loss: [1.42919312e+03 1.42909717e+03 9.59920660e-02]]
# Epoch: 15, [Real Discriminator :: Loss: 0.00037571051507256925], [ GAN :: Loss: [1.18343396e+03 1.18333801e+03 9.59927738e-02]]
# Epoch: 16, [Real Discriminator :: Loss: 0.0003369236073922366], [ GAN :: Loss: [1.55937585e+03 1.55927991e+03 9.59935077e-02]]
# Epoch: 16, [Real Discriminator :: Loss: 0.00044605685980059206], [ GAN :: Loss: [1.48222705e+03 1.48213110e+03 9.59942900e-02]]
# Epoch: 16, [Real Discriminator :: Loss: 0.00043173262383788824], [ GAN :: Loss: [1.48056909e+03 1.48047314e+03 9.59950723e-02]]
# Epoch: 16, [Real Discriminator :: Loss: 0.0003604727971833199], [ GAN :: Loss: [1.33589087e+03 1.33579492e+03 9.59957205e-02]]
# Epoch: 16, [Real Discriminator :: Loss: 0.0005459773819893599], [ GAN :: Loss: [1.34314954e+03 1.34305359e+03 9.59964134e-02]]
# Epoch: 16, [Real Discriminator :: Loss: 0.0003639250935520977], [ GAN :: Loss: [1.75224585e+03 1.75214990e+03 9.59969983e-02]]
# Epoch: 16, [Real Discriminator :: Loss: 0.00039126083720475435], [ GAN :: Loss: [1.24115674e+03 1.24106079e+03 9.59977061e-02]]
# Epoch: 16, [Real Discriminator :: Loss: 0.00035941036185249686], [ GAN :: Loss: [1.35864514e+03 1.35854919e+03 9.59983766e-02]]
# Epoch: 16, [Real Discriminator :: Loss: 0.0004373260890133679], [ GAN :: Loss: [1.87673193e+03 1.87663599e+03 9.59990285e-02]]
# Epoch: 16, [Real Discriminator :: Loss: 0.0003729577292688191], [ GAN :: Loss: [1.30289746e+03 1.30280151e+03 9.59996805e-02]]
# Epoch: 16, [Real Discriminator :: Loss: 0.0007599858799949288], [ GAN :: Loss: [1.25818787e+03 1.25809192e+03 9.60000008e-02]]
# Epoch: 16, [Real Discriminator :: Loss: 0.0008129434427246451], [ GAN :: Loss: [1.20042432e+03 1.20032837e+03 9.60000008e-02]]
# Epoch: 16, [Real Discriminator :: Loss: 0.0003847016778308898], [ GAN :: Loss: [1.71089307e+03 1.71079712e+03 9.60000008e-02]]
# Epoch: 16, [Real Discriminator :: Loss: 0.0007112896419130266], [ GAN :: Loss: [1.36627271e+03 1.36617676e+03 9.60000008e-02]]
# Epoch: 16, [Real Discriminator :: Loss: 0.0003994557773694396], [ GAN :: Loss: [1.59349829e+03 1.59340234e+03 9.60000008e-02]]
# Epoch: 16, [Real Discriminator :: Loss: 0.0004802557232324034], [ GAN :: Loss: [1.27000952e+03 1.26991357e+03 9.60000008e-02]]
# Epoch: 17, [Real Discriminator :: Loss: 0.00037421524757519364], [ GAN :: Loss: [1.14722314e+03 1.14712720e+03 9.60000008e-02]]
# Epoch: 17, [Real Discriminator :: Loss: 0.00047053597518242896], [ GAN :: Loss: [1.56523987e+03 1.56514392e+03 9.60000008e-02]]
# Epoch: 17, [Real Discriminator :: Loss: 0.0014324517687782645], [ GAN :: Loss: [1.52645630e+03 1.52636035e+03 9.60000008e-02]]
# Epoch: 17, [Real Discriminator :: Loss: 0.0009767577284947038], [ GAN :: Loss: [1.66385913e+03 1.66376318e+03 9.60000008e-02]]
# Epoch: 17, [Real Discriminator :: Loss: 0.0003703418478835374], [ GAN :: Loss: [1.38014868e+03 1.38005273e+03 9.60000008e-02]]
# Epoch: 17, [Real Discriminator :: Loss: 0.0011744546936824918], [ GAN :: Loss: [1.90417871e+03 1.90408276e+03 9.60000008e-02]]
# Epoch: 17, [Real Discriminator :: Loss: 0.000316778605338186], [ GAN :: Loss: [1.49841394e+03 1.49831799e+03 9.60000008e-02]]
# Epoch: 17, [Real Discriminator :: Loss: 0.00034667723230086267], [ GAN :: Loss: [1.61085913e+03 1.61076318e+03 9.60000008e-02]]
# Epoch: 17, [Real Discriminator :: Loss: 0.000358349148882553], [ GAN :: Loss: [1.13891797e+03 1.13882202e+03 9.60000008e-02]]
# Epoch: 17, [Real Discriminator :: Loss: 0.0006378645193763077], [ GAN :: Loss: [1.22039429e+03 1.22029834e+03 9.60000008e-02]]
# Epoch: 17, [Real Discriminator :: Loss: 0.00039927236502990127], [ GAN :: Loss: [1.68941467e+03 1.68931873e+03 9.60000008e-02]]
# Epoch: 17, [Real Discriminator :: Loss: 0.0003468293871264905], [ GAN :: Loss: [1.08782593e+03 1.08772998e+03 9.60000008e-02]]
# Epoch: 17, [Real Discriminator :: Loss: 0.0004317364364396781], [ GAN :: Loss: [1.79226709e+03 1.79217114e+03 9.60000008e-02]]
# Epoch: 17, [Real Discriminator :: Loss: 0.0003877035342156887], [ GAN :: Loss: [1.15799915e+03 1.15790320e+03 9.60000008e-02]]
# Epoch: 17, [Real Discriminator :: Loss: 0.0002795985492412001], [ GAN :: Loss: [1.57078308e+03 1.57068713e+03 9.60000008e-02]]
# Epoch: 17, [Real Discriminator :: Loss: 0.0003643372911028564], [ GAN :: Loss: [1.50567346e+03 1.50557751e+03 9.60000008e-02]]
# Epoch: 18, [Real Discriminator :: Loss: 0.00037068285746499896], [ GAN :: Loss: [1.29614075e+03 1.29604480e+03 9.60000008e-02]]
# Epoch: 18, [Real Discriminator :: Loss: 0.00032271072268486023], [ GAN :: Loss: [1.70099670e+03 1.70090076e+03 9.60000008e-02]]
# Epoch: 18, [Real Discriminator :: Loss: 0.00033541119773872197], [ GAN :: Loss: [1.78763147e+03 1.78753552e+03 9.60000008e-02]]
# Epoch: 18, [Real Discriminator :: Loss: 0.00037643301766365767], [ GAN :: Loss: [1.36867065e+03 1.36857471e+03 9.60000008e-02]]
# Epoch: 18, [Real Discriminator :: Loss: 0.0005169177311472595], [ GAN :: Loss: [1.69689233e+03 1.69679639e+03 9.60000008e-02]]
# Epoch: 18, [Real Discriminator :: Loss: 0.0003022901655640453], [ GAN :: Loss: [1.31021912e+03 1.31012317e+03 9.60000008e-02]]
# Epoch: 18, [Real Discriminator :: Loss: 0.0003717014624271542], [ GAN :: Loss: [1.32037390e+03 1.32027795e+03 9.60000008e-02]]
# Epoch: 18, [Real Discriminator :: Loss: 0.00035934129846282303], [ GAN :: Loss: [1.09446069e+03 1.09436475e+03 9.60000008e-02]]
# Epoch: 18, [Real Discriminator :: Loss: 0.00030113558750599623], [ GAN :: Loss: [1.18961230e+03 1.18951636e+03 9.60000008e-02]]
# Epoch: 18, [Real Discriminator :: Loss: 0.0005839510122314095], [ GAN :: Loss: [1.47418787e+03 1.47409192e+03 9.60000008e-02]]
# Epoch: 18, [Real Discriminator :: Loss: 0.00039255747105926275], [ GAN :: Loss: [1.52838953e+03 1.52829358e+03 9.60000008e-02]]
# Epoch: 18, [Real Discriminator :: Loss: 0.0003912456741090864], [ GAN :: Loss: [1.36377466e+03 1.36367871e+03 9.60000008e-02]]
# Epoch: 18, [Real Discriminator :: Loss: 0.00034676093491725624], [ GAN :: Loss: [1.41012549e+03 1.41002954e+03 9.60000008e-02]]
# Epoch: 18, [Real Discriminator :: Loss: 0.0002641738683450967], [ GAN :: Loss: [1.61925586e+03 1.61915991e+03 9.60000008e-02]]
# Epoch: 18, [Real Discriminator :: Loss: 0.00039281038334593177], [ GAN :: Loss: [1.50366028e+03 1.50356433e+03 9.60000008e-02]]
# Epoch: 18, [Real Discriminator :: Loss: 0.0008696027216501534], [ GAN :: Loss: [1.20101709e+03 1.20092114e+03 9.60000008e-02]]
# Epoch: 19, [Real Discriminator :: Loss: 0.0004854830040130764], [ GAN :: Loss: [1.22249109e+03 1.22239514e+03 9.60000008e-02]]
# Epoch: 19, [Real Discriminator :: Loss: 0.00033807370346039534], [ GAN :: Loss: [1.36036755e+03 1.36027161e+03 9.60000008e-02]]
# Epoch: 19, [Real Discriminator :: Loss: 0.0004229205078445375], [ GAN :: Loss: [1.70213110e+03 1.70203516e+03 9.60000008e-02]]
# Epoch: 19, [Real Discriminator :: Loss: 0.00030912732472643256], [ GAN :: Loss: [1.45991907e+03 1.45982312e+03 9.60000008e-02]]
# Epoch: 19, [Real Discriminator :: Loss: 0.0005251744878478348], [ GAN :: Loss: [1.36846387e+03 1.36836792e+03 9.60000008e-02]]
# Epoch: 19, [Real Discriminator :: Loss: 0.0002452792541589588], [ GAN :: Loss: [1.39430066e+03 1.39420471e+03 9.60000008e-02]]
# Epoch: 19, [Real Discriminator :: Loss: 0.0005803878884762526], [ GAN :: Loss: [1.77066064e+03 1.77056470e+03 9.60000008e-02]]
# Epoch: 19, [Real Discriminator :: Loss: 0.00037588231498375535], [ GAN :: Loss: [1.31207654e+03 1.31198059e+03 9.60000008e-02]]
# Epoch: 19, [Real Discriminator :: Loss: 0.0003467767091933638], [ GAN :: Loss: [1.23892517e+03 1.23882922e+03 9.60000008e-02]]
# Epoch: 19, [Real Discriminator :: Loss: 0.00030322716338559985], [ GAN :: Loss: [1.18071277e+03 1.18061682e+03 9.60000008e-02]]
# Epoch: 19, [Real Discriminator :: Loss: 0.00028163817478343844], [ GAN :: Loss: [1.57101270e+03 1.57091675e+03 9.60000008e-02]]
# Epoch: 19, [Real Discriminator :: Loss: 0.00034507710370235145], [ GAN :: Loss: [1.40303271e+03 1.40293677e+03 9.60000008e-02]]
# Epoch: 19, [Real Discriminator :: Loss: 0.0003905054763890803], [ GAN :: Loss: [1.58980713e+03 1.58971118e+03 9.60000008e-02]]
# Epoch: 19, [Real Discriminator :: Loss: 0.00036579431616701186], [ GAN :: Loss: [1.21244910e+03 1.21235315e+03 9.60000008e-02]]
# Epoch: 19, [Real Discriminator :: Loss: 0.00042575635598041117], [ GAN :: Loss: [1.30606628e+03 1.30597034e+03 9.60000008e-02]]
# Epoch: 19, [Real Discriminator :: Loss: 0.0002079714904539287], [ GAN :: Loss: [1.58105029e+03 1.58095435e+03 9.60000008e-02]]
# Epoch: 20, [Real Discriminator :: Loss: 0.0004799348535016179], [ GAN :: Loss: [1.26223474e+03 1.26213879e+03 9.60000008e-02]]
# Epoch: 20, [Real Discriminator :: Loss: 0.0004175941867288202], [ GAN :: Loss: [1.04728027e+03 1.04718433e+03 9.60000008e-02]]
# Epoch: 20, [Real Discriminator :: Loss: 0.00043199051287956536], [ GAN :: Loss: [1.56618994e+03 1.56609399e+03 9.60000008e-02]]
# ...
# Epoch: 23, [Real Discriminator :: Loss: 0.0002713465364649892], [ GAN :: Loss: [1.71994385e+03 1.71984790e+03 9.60000008e-02]]
# Epoch: 23, [Real Discriminator :: Loss: 0.00024347027647309005], [ GAN :: Loss: [1.52532996e+03 1.52523401e+03 9.60000008e-02]]
# Epoch: 23, [Real Discriminator :: Loss: 0.00022162597451824695], [ GAN :: Loss: [1.23787390e+03 1.23777795e+03 9.60000008e-02]]
# Epoch: 23, [Real Discriminator :: Loss: 0.00026965668075717986], [ GAN :: Loss: [1.72633191e+03 1.72623596e+03 9.60000008e-02]]
# Epoch: 23, [Real Discriminator :: Loss: 0.00023920442617964], [ GAN :: Loss: [1.66454712e+03 1.66445117e+03 9.60000008e-02]]
# Epoch: 23, [Real Discriminator :: Loss: 0.00024163900525309145], [ GAN :: Loss: [9.76153198e+02 9.76057190e+02 9.60000008e-02]]
# Epoch: 23, [Real Discriminator :: Loss: 0.0002832455502357334], [ GAN :: Loss: [1.66558191e+03 1.66548596e+03 9.60000008e-02]]
# Epoch: 23, [Real Discriminator :: Loss: 0.0004123908292967826], [ GAN :: Loss: [1.38952075e+03 1.38942480e+03 9.60000008e-02]]
# Epoch: 23, [Real Discriminator :: Loss: 0.0001878093316918239], [ GAN :: Loss: [1.46761353e+03 1.46751758e+03 9.60000008e-02]]
# Epoch: 23, [Real Discriminator :: Loss: 0.00018958086729981005], [ GAN :: Loss: [1.41570593e+03 1.41560999e+03 9.60000008e-02]]
# Epoch: 24, [Real Discriminator :: Loss: 0.0005559553974308074], [ GAN :: Loss: [1.45400708e+03 1.45391113e+03 9.60000008e-02]]
# Epoch: 24, [Real Discriminator :: Loss: 0.00025859876768663526], [ GAN :: Loss: [1.73035071e+03 1.73025476e+03 9.60000008e-02]]
# Epoch: 24, [Real Discriminator :: Loss: 0.00020669489458668977], [ GAN :: Loss: [1.84176904e+03 1.84167310e+03 9.60000008e-02]]
# Epoch: 24, [Real Discriminator :: Loss: 0.0001994811900658533], [ GAN :: Loss: [1.85110388e+03 1.85100793e+03 9.60000008e-02]]
# Epoch: 24, [Real Discriminator :: Loss: 0.00025400888989679515], [ GAN :: Loss: [1.38315833e+03 1.38306238e+03 9.60000008e-02]]
# Epoch: 24, [Real Discriminator :: Loss: 0.0001810771063901484], [ GAN :: Loss: [1.28710986e+03 1.28701392e+03 9.60000008e-02]]
# Epoch: 24, [Real Discriminator :: Loss: 0.000329304370097816], [ GAN :: Loss: [1.14014795e+03 1.14005200e+03 9.60000008e-02]]
# Epoch: 24, [Real Discriminator :: Loss: 0.0004136427887715399], [ GAN :: Loss: [1.83745471e+03 1.83735876e+03 9.60000008e-02]]
# Epoch: 24, [Real Discriminator :: Loss: 0.00026538691599853337], [ GAN :: Loss: [1.78821509e+03 1.78811914e+03 9.60000008e-02]]
# Epoch: 24, [Real Discriminator :: Loss: 0.00042752225999720395], [ GAN :: Loss: [1.01491760e+03 1.01482159e+03 9.60000008e-02]]
# Epoch: 24, [Real Discriminator :: Loss: 0.00036828851443715394], [ GAN :: Loss: [1.23243274e+03 1.23233679e+03 9.60000008e-02]]
# Epoch: 24, [Real Discriminator :: Loss: 0.00032895506592467427], [ GAN :: Loss: [1.66886072e+03 1.66876477e+03 9.60000008e-02]]
# Epoch: 24, [Real Discriminator :: Loss: 0.00018380848632659763], [ GAN :: Loss: [1.19210767e+03 1.19201172e+03 9.60000008e-02]]
# Epoch: 24, [Real Discriminator :: Loss: 0.00028338393894955516], [ GAN :: Loss: [1.42022546e+03 1.42012952e+03 9.60000008e-02]]
# Epoch: 24, [Real Discriminator :: Loss: 0.00020148583280388266], [ GAN :: Loss: [1.76050916e+03 1.76041321e+03 9.60000008e-02]]
# Epoch: 24, [Real Discriminator :: Loss: 0.00028735672822222114], [ GAN :: Loss: [9.18901855e+02 9.18805847e+02 9.60000008e-02]]
# Epoch: 25, [Real Discriminator :: Loss: 0.00027518521528691053], [ GAN :: Loss: [1.50239917e+03 1.50230322e+03 9.60000008e-02]]
# Epoch: 25, [Real Discriminator :: Loss: 0.000217988999793306], [ GAN :: Loss: [1.58552075e+03 1.58542480e+03 9.60000008e-02]]
# Epoch: 25, [Real Discriminator :: Loss: 0.00022906911908648908], [ GAN :: Loss: [1.37954236e+03 1.37944641e+03 9.60000008e-02]]
# Epoch: 25, [Real Discriminator :: Loss: 0.00022073621221352369], [ GAN :: Loss: [1.38671069e+03 1.38661475e+03 9.60000008e-02]]
# Epoch: 25, [Real Discriminator :: Loss: 0.0003144059737678617], [ GAN :: Loss: [1.26502954e+03 1.26493359e+03 9.60000008e-02]]
# Epoch: 25, [Real Discriminator :: Loss: 0.0003001740842591971], [ GAN :: Loss: [1.61217346e+03 1.61207751e+03 9.60000008e-02]]
# Epoch: 25, [Real Discriminator :: Loss: 0.0002927905006799847], [ GAN :: Loss: [1.17130554e+03 1.17120959e+03 9.60000008e-02]]
# Epoch: 25, [Real Discriminator :: Loss: 0.0002772753359749913], [ GAN :: Loss: [1.35572314e+03 1.35562720e+03 9.60000008e-02]]
# Epoch: 25, [Real Discriminator :: Loss: 0.0005283094942569733], [ GAN :: Loss: [1.45400708e+03 1.45391113e+03 9.60000008e-02]]
# Epoch: 25, [Real Discriminator :: Loss: 0.00021167336672078818], [ GAN :: Loss: [1.37526514e+03 1.37516919e+03 9.60000008e-02]]
# Epoch: 25, [Real Discriminator :: Loss: 0.00025273096980527043], [ GAN :: Loss: [1.53170068e+03 1.53160474e+03 9.60000008e-02]]
# Epoch: 25, [Real Discriminator :: Loss: 0.00022139701468404382], [ GAN :: Loss: [1.28279675e+03 1.28270081e+03 9.60000008e-02]]
# Epoch: 25, [Real Discriminator :: Loss: 0.00028262805426493287], [ GAN :: Loss: [1.03327722e+03 1.03318127e+03 9.60000008e-02]]
# Epoch: 25, [Real Discriminator :: Loss: 0.00018451495270710438], [ GAN :: Loss: [1.62576868e+03 1.62567273e+03 9.60000008e-02]]
# Epoch: 25, [Real Discriminator :: Loss: 0.00030977648566477], [ GAN :: Loss: [9.57289001e+02 9.57192993e+02 9.60000008e-02]]
# Epoch: 25, [Real Discriminator :: Loss: 0.0003973034326918423], [ GAN :: Loss: [1.15186548e+03 1.15176953e+03 9.60000008e-02]]
# Epoch: 26, [Real Discriminator :: Loss: 0.00039615060086362064], [ GAN :: Loss: [1.39889551e+03 1.39879956e+03 9.60000008e-02]]
# Epoch: 26, [Real Discriminator :: Loss: 0.0001478921330999583], [ GAN :: Loss: [1.21801038e+03 1.21791443e+03 9.60000008e-02]]
# Epoch: 26, [Real Discriminator :: Loss: 0.00036747759440913796], [ GAN :: Loss: [1.53782227e+03 1.53772632e+03 9.60000008e-02]]
# Epoch: 26, [Real Discriminator :: Loss: 0.0001453118893550709], [ GAN :: Loss: [1.50972949e+03 1.50963354e+03 9.60000008e-02]]
# Epoch: 26, [Real Discriminator :: Loss: 0.00021414196817204356], [ GAN :: Loss: [1.18366516e+03 1.18356921e+03 9.60000008e-02]]
# Epoch: 26, [Real Discriminator :: Loss: 0.00013445137301459908], [ GAN :: Loss: [1.21047351e+03 1.21037756e+03 9.60000008e-02]]
# Epoch: 26, [Real Discriminator :: Loss: 0.00028651513275690377], [ GAN :: Loss: [1.27908508e+03 1.27898914e+03 9.60000008e-02]]
# Epoch: 26, [Real Discriminator :: Loss: 0.0002660682366695255], [ GAN :: Loss: [1.47208911e+03 1.47199316e+03 9.60000008e-02]]
# Epoch: 26, [Real Discriminator :: Loss: 0.00026936110225506127], [ GAN :: Loss: [1.59497754e+03 1.59488159e+03 9.60000008e-02]]
# Epoch: 26, [Real Discriminator :: Loss: 0.0002051632181974128], [ GAN :: Loss: [1.44462793e+03 1.44453198e+03 9.60000008e-02]]
# Epoch: 26, [Real Discriminator :: Loss: 0.00020806190150324255], [ GAN :: Loss: [1.34496228e+03 1.34486633e+03 9.60000008e-02]]
# Epoch: 26, [Real Discriminator :: Loss: 0.00030316031188704073], [ GAN :: Loss: [1.39858191e+03 1.39848596e+03 9.60000008e-02]]
# Epoch: 26, [Real Discriminator :: Loss: 0.0003112724225502461], [ GAN :: Loss: [1.34893628e+03 1.34884033e+03 9.60000008e-02]]
# Epoch: 26, [Real Discriminator :: Loss: 0.00018398737302049994], [ GAN :: Loss: [1.51650916e+03 1.51641321e+03 9.60000008e-02]]
# Epoch: 26, [Real Discriminator :: Loss: 0.00016886969387996942], [ GAN :: Loss: [1.37507031e+03 1.37497437e+03 9.60000008e-02]]
# Epoch: 26, [Real Discriminator :: Loss: 0.0003488658112473786], [ GAN :: Loss: [1.20755469e+03 1.20745874e+03 9.60000008e-02]]
# Epoch: 27, [Real Discriminator :: Loss: 0.0003365572483744472], [ GAN :: Loss: [1.42839832e+03 1.42830237e+03 9.60000008e-02]]
# Epoch: 27, [Real Discriminator :: Loss: 0.00016681381384842098], [ GAN :: Loss: [1.60105835e+03 1.60096240e+03 9.60000008e-02]]
# Epoch: 27, [Real Discriminator :: Loss: 0.00015015182725619525], [ GAN :: Loss: [1.48512109e+03 1.48502515e+03 9.60000008e-02]]
# Epoch: 27, [Real Discriminator :: Loss: 0.0002582215238362551], [ GAN :: Loss: [1.36412634e+03 1.36403040e+03 9.60000008e-02]]
# Epoch: 27, [Real Discriminator :: Loss: 0.00023478679941035807], [ GAN :: Loss: [1.43517114e+03 1.43507520e+03 9.60000008e-02]]
# Epoch: 27, [Real Discriminator :: Loss: 0.0001927480916492641], [ GAN :: Loss: [1.46781873e+03 1.46772278e+03 9.60000008e-02]]
# Epoch: 27, [Real Discriminator :: Loss: 0.00014096344239078462], [ GAN :: Loss: [1.38539709e+03 1.38530115e+03 9.60000008e-02]]
# Epoch: 27, [Real Discriminator :: Loss: 0.00014892096805851907], [ GAN :: Loss: [1.60568909e+03 1.60559314e+03 9.60000008e-02]]
# Epoch: 27, [Real Discriminator :: Loss: 0.00017177769041154534], [ GAN :: Loss: [1.37352991e+03 1.37343396e+03 9.60000008e-02]]
# Epoch: 27, [Real Discriminator :: Loss: 0.00014740046754013747], [ GAN :: Loss: [1.04180347e+03 1.04170752e+03 9.60000008e-02]]
# Epoch: 27, [Real Discriminator :: Loss: 0.00015692498709540814], [ GAN :: Loss: [1.21657117e+03 1.21647522e+03 9.60000008e-02]]
# Epoch: 27, [Real Discriminator :: Loss: 0.0002428816951578483], [ GAN :: Loss: [1.26123511e+03 1.26113916e+03 9.60000008e-02]]
# Epoch: 27, [Real Discriminator :: Loss: 0.0007193332421593368], [ GAN :: Loss: [1.40821228e+03 1.40811633e+03 9.60000008e-02]]
# Epoch: 27, [Real Discriminator :: Loss: 0.0001947113632922992], [ GAN :: Loss: [1.33953430e+03 1.33943835e+03 9.60000008e-02]]
# Epoch: 27, [Real Discriminator :: Loss: 0.000167231701198034], [ GAN :: Loss: [1.27315674e+03 1.27306079e+03 9.60000008e-02]]
# Epoch: 27, [Real Discriminator :: Loss: 0.00017920020036399364], [ GAN :: Loss: [1.51666797e+03 1.51657202e+03 9.60000008e-02]]
# Epoch: 28, [Real Discriminator :: Loss: 0.00018562516197562218], [ GAN :: Loss: [1.37997986e+03 1.37988391e+03 9.60000008e-02]]
# Epoch: 28, [Real Discriminator :: Loss: 0.00024932564701884985], [ GAN :: Loss: [1.34523828e+03 1.34514233e+03 9.60000008e-02]]
# Epoch: 28, [Real Discriminator :: Loss: 0.0005236668512225151], [ GAN :: Loss: [1.28682397e+03 1.28672803e+03 9.60000008e-02]]
# Epoch: 28, [Real Discriminator :: Loss: 0.0002642642648424953], [ GAN :: Loss: [1.58731665e+03 1.58722070e+03 9.60000008e-02]]
# Epoch: 28, [Real Discriminator :: Loss: 0.00030645105289295316], [ GAN :: Loss: [2.05441992e+03 2.05432397e+03 9.60000008e-02]]
# Epoch: 28, [Real Discriminator :: Loss: 0.00024890623171813786], [ GAN :: Loss: [1.88540869e+03 1.88531274e+03 9.60000008e-02]]
# Epoch: 28, [Real Discriminator :: Loss: 0.00012849322229158133], [ GAN :: Loss: [1.54824585e+03 1.54814990e+03 9.60000008e-02]]
# Epoch: 28, [Real Discriminator :: Loss: 0.0002972512738779187], [ GAN :: Loss: [1.33538196e+03 1.33528601e+03 9.60000008e-02]]
# Epoch: 28, [Real Discriminator :: Loss: 0.00019345954933669418], [ GAN :: Loss: [1.51571472e+03 1.51561877e+03 9.60000008e-02]]
# Epoch: 28, [Real Discriminator :: Loss: 0.00018446978356223553], [ GAN :: Loss: [1.42156909e+03 1.42147314e+03 9.60000008e-02]]
# Epoch: 28, [Real Discriminator :: Loss: 0.00019002804765477777], [ GAN :: Loss: [1.42303467e+03 1.42293872e+03 9.60000008e-02]]
# Epoch: 28, [Real Discriminator :: Loss: 0.0001798450539354235], [ GAN :: Loss: [1.22209192e+03 1.22199597e+03 9.60000008e-02]]
# Epoch: 28, [Real Discriminator :: Loss: 0.00023323591449297965], [ GAN :: Loss: [1.35833313e+03 1.35823718e+03 9.60000008e-02]]
# Epoch: 28, [Real Discriminator :: Loss: 0.0001696170656941831], [ GAN :: Loss: [1.35390833e+03 1.35381238e+03 9.60000008e-02]]
# Epoch: 28, [Real Discriminator :: Loss: 0.00017111891065724194], [ GAN :: Loss: [1.37460913e+03 1.37451318e+03 9.60000008e-02]]
# Epoch: 28, [Real Discriminator :: Loss: 0.00037196470657363534], [ GAN :: Loss: [2.04306311e+03 2.04296716e+03 9.60000008e-02]]
# Epoch: 29, [Real Discriminator :: Loss: 0.00021707479027099907], [ GAN :: Loss: [1.04234277e+03 1.04224683e+03 9.60000008e-02]]
# Epoch: 29, [Real Discriminator :: Loss: 0.00015386470477096736], [ GAN :: Loss: [1.55375354e+03 1.55365759e+03 9.60000008e-02]]
# Epoch: 29, [Real Discriminator :: Loss: 0.00021376629592850804], [ GAN :: Loss: [1.56779065e+03 1.56769470e+03 9.60000008e-02]]
# Epoch: 29, [Real Discriminator :: Loss: 0.0002880381653085351], [ GAN :: Loss: [1.27007629e+03 1.26998035e+03 9.60000008e-02]]
# Epoch: 29, [Real Discriminator :: Loss: 0.00016491329006385058], [ GAN :: Loss: [1.24007666e+03 1.23998071e+03 9.60000008e-02]]
# Epoch: 29, [Real Discriminator :: Loss: 0.0004153073241468519], [ GAN :: Loss: [1.49732190e+03 1.49722595e+03 9.60000008e-02]]
# Epoch: 29, [Real Discriminator :: Loss: 0.00031581413350068033], [ GAN :: Loss: [1.19680347e+03 1.19670752e+03 9.60000008e-02]]
# Epoch: 29, [Real Discriminator :: Loss: 0.00016071026038844138], [ GAN :: Loss: [1.46838477e+03 1.46828882e+03 9.60000008e-02]]
# Epoch: 29, [Real Discriminator :: Loss: 0.0001776302233338356], [ GAN :: Loss: [1.17763916e+03 1.17754321e+03 9.60000008e-02]]
# Epoch: 29, [Real Discriminator :: Loss: 0.00019798497669398785], [ GAN :: Loss: [1.68323596e+03 1.68314001e+03 9.60000008e-02]]
# Epoch: 29, [Real Discriminator :: Loss: 0.00023126155429054052], [ GAN :: Loss: [1.33866431e+03 1.33856836e+03 9.60000008e-02]]
# Epoch: 29, [Real Discriminator :: Loss: 0.00028953549917787313], [ GAN :: Loss: [1.24770227e+03 1.24760632e+03 9.60000008e-02]]
# Epoch: 29, [Real Discriminator :: Loss: 0.00019071646966040134], [ GAN :: Loss: [1.21329272e+03 1.21319678e+03 9.60000008e-02]]
# Epoch: 29, [Real Discriminator :: Loss: 0.0003414046950638294], [ GAN :: Loss: [1.28451514e+03 1.28441919e+03 9.60000008e-02]]
# Epoch: 29, [Real Discriminator :: Loss: 0.000157225935254246], [ GAN :: Loss: [1.46288513e+03 1.46278918e+03 9.60000008e-02]]
# Epoch: 29, [Real Discriminator :: Loss: 0.00018192121933680028], [ GAN :: Loss: [1.40017065e+03 1.40007471e+03 9.60000008e-02]]
# Epoch: 30, [Real Discriminator :: Loss: 0.00029004018870182335], [ GAN :: Loss: [1.57113953e+03 1.57104358e+03 9.60000008e-02]]
# Epoch: 30, [Real Discriminator :: Loss: 0.0005971461650915444], [ GAN :: Loss: [1.19783313e+03 1.19773718e+03 9.60000008e-02]]
# Epoch: 30, [Real Discriminator :: Loss: 0.00016098040214274079], [ GAN :: Loss: [1.25608826e+03 1.25599231e+03 9.60000008e-02]]
# Epoch: 30, [Real Discriminator :: Loss: 0.00032066006679087877], [ GAN :: Loss: [1.54357507e+03 1.54347913e+03 9.60000008e-02]]
# Epoch: 30, [Real Discriminator :: Loss: 0.000245173170696944], [ GAN :: Loss: [1.51340747e+03 1.51331152e+03 9.60000008e-02]]
# Epoch: 30, [Real Discriminator :: Loss: 0.0004146621795371175], [ GAN :: Loss: [1.89561035e+03 1.89551440e+03 9.60000008e-02]]
# Epoch: 30, [Real Discriminator :: Loss: 0.0002360006037633866], [ GAN :: Loss: [1.59245068e+03 1.59235474e+03 9.60000008e-02]]
# Epoch: 30, [Real Discriminator :: Loss: 0.0001554403715999797], [ GAN :: Loss: [1.20387793e+03 1.20378198e+03 9.60000008e-02]]
# Epoch: 30, [Real Discriminator :: Loss: 0.0004311725788284093], [ GAN :: Loss: [1.34641870e+03 1.34632275e+03 9.60000008e-02]]
# Epoch: 30, [Real Discriminator :: Loss: 0.0002205053169745952], [ GAN :: Loss: [1.87323633e+03 1.87314038e+03 9.60000008e-02]]
# Epoch: 30, [Real Discriminator :: Loss: 0.0003233589814044535], [ GAN :: Loss: [1.43134753e+03 1.43125159e+03 9.60000008e-02]]
# Epoch: 30, [Real Discriminator :: Loss: 0.00020612827211152762], [ GAN :: Loss: [1.18631714e+03 1.18622119e+03 9.60000008e-02]]
# Epoch: 30, [Real Discriminator :: Loss: 0.00021515203115995973], [ GAN :: Loss: [1.61144629e+03 1.61135034e+03 9.60000008e-02]]
# Epoch: 30, [Real Discriminator :: Loss: 0.0002032907650573179], [ GAN :: Loss: [1.65001355e+03 1.64991760e+03 9.60000008e-02]]
# Epoch: 30, [Real Discriminator :: Loss: 0.0002567170886322856], [ GAN :: Loss: [1.20089954e+03 1.20080359e+03 9.60000008e-02]]
# Epoch: 30, [Real Discriminator :: Loss: 0.0002897813974414021], [ GAN :: Loss: [1.24448987e+03 1.24439392e+03 9.60000008e-02]]
# Epoch: 31, [Real Discriminator :: Loss: 0.00012937850260641426], [ GAN :: Loss: [1.56560791e+03 1.56551196e+03 9.60000008e-02]]
# Epoch: 31, [Real Discriminator :: Loss: 0.000221482157940045], [ GAN :: Loss: [1.24378162e+03 1.24368567e+03 9.60000008e-02]]
# Epoch: 31, [Real Discriminator :: Loss: 0.00016906679957173765], [ GAN :: Loss: [1.21812830e+03 1.21803235e+03 9.60000008e-02]]
