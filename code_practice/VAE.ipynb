# %% [markdown]
# <a href="https://colab.research.google.com/github/thwlswkdgh/GAN/blob/main/code_practice/VAE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Git clone

# %%
# !git clone https://github.com/davidADSP/GDL_code
# Out:
# Cloning into 'GDL_code'...
# remote: Enumerating objects: 391, done.
# remote: Total 391 (delta 0), reused 0 (delta 0), pack-reused 391
# Receiving objects: 100% (391/391), 22.13 MiB | 23.39 MiB/s, done.
# Resolving deltas: 100% (237/237), done.

# %% [markdown]
# ### ipynb 합치기

# %%
#!pip install nbmerge
##nbmerge file_1.ipynb file_2.ipynb file_3.ipynb > merged.ipynb
# Out:
# Collecting nbmerge
#   Downloading nbmerge-0.0.4.tar.gz (7.6 kB)
# Building wheels for collected packages: nbmerge
#   Building wheel for nbmerge (setup.py) ... done
#   Created wheel for nbmerge: filename=nbmerge-0.0.4-py2.py3-none-any.whl size=6413 sha256=f6bc00dd94b6ab5f06894ed8740d0459a544b611c4ce0e5a45a4a17ec2b9474e
#   Stored in directory: /root/.cache/pip/wheels/ce/2d/ef/1833d9299f557279f700d29a3355ad2b5fa9e35c32f84c5b3a
# Successfully built nbmerge
# Installing collected packages: nbmerge
# Successfully installed nbmerge-0.0.4

# %% [markdown]
# ### Gdrive mount

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 경로 이동

# %%
# %cd /content/drive/MyDrive/GAN/GAN2_Src
# Out:
# /content/drive/MyDrive/GAN/GAN2_Src

# %%
# !pwd
# Out:
# /content/drive/MyDrive/GAN/GAN2_Src

# %%
# !ls
# Out:
# 03_01_autoencoder.ipynb  celeba-dataset      GDL_code	  requirements.txt
# 03_02_vae_digit.ipynb	 celeba-dataset.zip  kaggle.json  run
# 03_03_vae_face.ipynb	 Common.ipynb	     models	  utils

# %% [markdown]
# ### 환경 설정(PIP install requirements)

# %%
# !pip install -r requirements.txt
# Out:
# Collecting git+https://www.github.com/keras-team/keras-contrib.git (from -r requirements.txt (line 29))
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-sjvru7a1
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-sjvru7a1
# Collecting absl-py==0.7.0
#   Downloading absl-py-0.7.0.tar.gz (96 kB)
#      |████████████████████████████████| 96 kB 3.4 MB/s
# Collecting appnope==0.1.0
#   Downloading appnope-0.1.0-py2.py3-none-any.whl (4.0 kB)
# Collecting astor==0.7.1
#   Downloading astor-0.7.1-py2.py3-none-any.whl (27 kB)
# Collecting backcall==0.1.0
#   Downloading backcall-0.1.0.zip (11 kB)
# Collecting bleach==3.1.0
#   Downloading bleach-3.1.0-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 72.7 MB/s
# Collecting cloudpickle==0.8.0
#   Downloading cloudpickle-0.8.0-py2.py3-none-any.whl (16 kB)
# Collecting cycler==0.10.0
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting dask==1.1.1
#   Downloading dask-1.1.1-py2.py3-none-any.whl (701 kB)
#      |████████████████████████████████| 701 kB 67.8 MB/s
# Collecting decorator==4.3.2
#   Downloading decorator-4.3.2-py2.py3-none-any.whl (9.1 kB)
# Collecting defusedxml==0.5.0
#   Downloading defusedxml-0.5.0-py2.py3-none-any.whl (33 kB)
# Collecting entrypoints==0.3
#   Downloading entrypoints-0.3-py2.py3-none-any.whl (11 kB)
# Collecting gast==0.2.2
#   Downloading gast-0.2.2.tar.gz (10 kB)
# Collecting grpcio==1.18.0
#   Downloading grpcio-1.18.0-cp37-cp37m-manylinux1_x86_64.whl (10.6 MB)
#      |████████████████████████████████| 10.6 MB 59.4 MB/s
# Collecting h5py==2.9.0
#   Downloading h5py-2.9.0-cp37-cp37m-manylinux1_x86_64.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 52.3 MB/s
# Collecting ipykernel==5.1.0
#   Downloading ipykernel-5.1.0-py3-none-any.whl (113 kB)
#      |████████████████████████████████| 113 kB 55.5 MB/s
# Collecting ipython==7.3.0
#   Downloading ipython-7.3.0-py3-none-any.whl (768 kB)
#      |████████████████████████████████| 768 kB 72.5 MB/s
# Requirement already satisfied: ipython-genutils==0.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 17)) (0.2.0)
# Collecting ipywidgets==7.4.2
#   Downloading ipywidgets-7.4.2-py2.py3-none-any.whl (111 kB)
#      |████████████████████████████████| 111 kB 68.6 MB/s
# Collecting jedi==0.13.2
#   Downloading jedi-0.13.2-py2.py3-none-any.whl (177 kB)
#      |████████████████████████████████| 177 kB 59.3 MB/s
# Collecting Jinja2==2.10
#   Downloading Jinja2-2.10-py2.py3-none-any.whl (126 kB)
#      |████████████████████████████████| 126 kB 50.4 MB/s
# Collecting jsonschema==2.6.0
#   Downloading jsonschema-2.6.0-py2.py3-none-any.whl (39 kB)
# Requirement already satisfied: jupyter==1.0.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 22)) (1.0.0)
# Collecting jupyter-client==5.2.4
#   Downloading jupyter_client-5.2.4-py2.py3-none-any.whl (89 kB)
#      |████████████████████████████████| 89 kB 6.9 MB/s
# Collecting jupyter-console==6.0.0
#   Downloading jupyter_console-6.0.0-py2.py3-none-any.whl (21 kB)
# Collecting jupyter-core==4.4.0
#   Downloading jupyter_core-4.4.0-py2.py3-none-any.whl (126 kB)
#      |████████████████████████████████| 126 kB 66.8 MB/s
# Collecting Keras==2.2.4
#   Downloading Keras-2.2.4-py2.py3-none-any.whl (312 kB)
#      |████████████████████████████████| 312 kB 68.6 MB/s
# Collecting Keras-Applications==1.0.7
#   Downloading Keras_Applications-1.0.7-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 335 kB/s
# Collecting Keras-Preprocessing==1.0.9
#   Downloading Keras_Preprocessing-1.0.9-py2.py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 4.6 MB/s
# Collecting kiwisolver==1.0.1
#   Downloading kiwisolver-1.0.1-cp37-cp37m-manylinux1_x86_64.whl (89 kB)
#      |████████████████████████████████| 89 kB 5.7 MB/s
# Collecting Markdown==3.0.1
#   Downloading Markdown-3.0.1-py2.py3-none-any.whl (89 kB)
#      |████████████████████████████████| 89 kB 5.6 MB/s
# Collecting MarkupSafe==1.1.0
#   Downloading MarkupSafe-1.1.0-cp37-cp37m-manylinux1_x86_64.whl (27 kB)
# Collecting matplotlib==3.0.2
#   Downloading matplotlib-3.0.2-cp37-cp37m-manylinux1_x86_64.whl (12.9 MB)
#      |████████████████████████████████| 12.9 MB 54.0 MB/s
# Requirement already satisfied: mistune==0.8.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 34)) (0.8.4)
# Requirement already satisfied: music21==5.5.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 35)) (5.5.0)
# Collecting nbconvert==5.4.1
#   Downloading nbconvert-5.4.1-py2.py3-none-any.whl (407 kB)
#      |████████████████████████████████| 407 kB 70.5 MB/s
# Collecting nbformat==4.4.0
#   Downloading nbformat-4.4.0-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 61.6 MB/s
# Collecting networkx==2.2
#   Downloading networkx-2.2.zip (1.7 MB)
#      |████████████████████████████████| 1.7 MB 50.9 MB/s
# Collecting notebook==5.7.4
#   Downloading notebook-5.7.4-py2.py3-none-any.whl (9.0 MB)
#      |████████████████████████████████| 9.0 MB 71.3 MB/s
# Collecting numpy==1.16.1
#   Downloading numpy-1.16.1-cp37-cp37m-manylinux1_x86_64.whl (17.3 MB)
#      |████████████████████████████████| 17.3 MB 749 kB/s
# Collecting xarray==0.14.0
#   Downloading xarray-0.14.0-py3-none-any.whl (598 kB)
#      |████████████████████████████████| 598 kB 79.5 MB/s
# Collecting pandas==0.24.2
#   Downloading pandas-0.24.2-cp37-cp37m-manylinux1_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 54.1 MB/s
# Collecting pandocfilters==1.4.2
#   Downloading pandocfilters-1.4.2.tar.gz (14 kB)
# Collecting parso==0.3.4
#   Downloading parso-0.3.4-py2.py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 1.3 MB/s
# Collecting pexpect==4.6.0
#   Downloading pexpect-4.6.0-py2.py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 3.8 MB/s
# Requirement already satisfied: pickleshare==0.7.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 46)) (0.7.5)
# Collecting Pillow==5.4.1
#   Downloading Pillow-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 62.7 MB/s
# Collecting prometheus-client==0.6.0
#   Downloading prometheus_client-0.6.0.tar.gz (36 kB)
# Collecting prompt-toolkit==2.0.9
#   Downloading prompt_toolkit-2.0.9-py3-none-any.whl (337 kB)
#      |████████████████████████████████| 337 kB 81.0 MB/s
# Collecting protobuf==3.6.1
#   Downloading protobuf-3.6.1-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 53.4 MB/s
# Collecting ptyprocess==0.6.0
#   Downloading ptyprocess-0.6.0-py2.py3-none-any.whl (39 kB)
# Collecting pydot==1.4.1
#   Downloading pydot-1.4.1-py2.py3-none-any.whl (19 kB)
# Collecting Pygments==2.3.1
#   Downloading Pygments-2.3.1-py2.py3-none-any.whl (849 kB)
#      |████████████████████████████████| 849 kB 64.9 MB/s
# Collecting pyparsing==2.3.1
#   Downloading pyparsing-2.3.1-py2.py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 215 kB/s
# Collecting python-dateutil==2.8.0
#   Downloading python_dateutil-2.8.0-py2.py3-none-any.whl (226 kB)
#      |████████████████████████████████| 226 kB 71.0 MB/s
# Requirement already satisfied: pytz==2018.9 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 56)) (2018.9)
# Collecting PyWavelets==1.0.1
#   Downloading PyWavelets-1.0.1-cp37-cp37m-manylinux1_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 51.2 MB/s
# Requirement already satisfied: PyYAML==3.13 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 58)) (3.13)
# Collecting pyzmq==18.0.0
#   Downloading pyzmq-18.0.0-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 60.9 MB/s
# Collecting qtconsole==4.4.3
#   Downloading qtconsole-4.4.3-py2.py3-none-any.whl (113 kB)
#      |████████████████████████████████| 113 kB 69.2 MB/s
# Collecting scikit-image==0.14.2
#   Downloading scikit_image-0.14.2-cp37-cp37m-manylinux1_x86_64.whl (25.3 MB)
#      |████████████████████████████████| 25.3 MB 1.3 MB/s
# Collecting scipy==1.2.1
#   Downloading scipy-1.2.1-cp37-cp37m-manylinux1_x86_64.whl (24.8 MB)
#      |████████████████████████████████| 24.8 MB 1.3 MB/s
# Collecting Send2Trash==1.5.0
#   Downloading Send2Trash-1.5.0-py3-none-any.whl (12 kB)
# Collecting six==1.12.0
#   Downloading six-1.12.0-py2.py3-none-any.whl (10 kB)
# Collecting tensorboard==1.14.0
#   Downloading tensorboard-1.14.0-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 59.1 MB/s
# Collecting tensorflow==1.14.0
#   Downloading tensorflow-1.14.0-cp37-cp37m-manylinux1_x86_64.whl (109.3 MB)
#      |████████████████████████████████| 109.3 MB 74 kB/s
# Requirement already satisfied: termcolor==1.1.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 67)) (1.1.0)
# Collecting terminado==0.8.1
#   Downloading terminado-0.8.1-py2.py3-none-any.whl (33 kB)
# Collecting testpath==0.4.2
#   Downloading testpath-0.4.2-py2.py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 74.3 MB/s
# Collecting toolz==0.9.0
#   Downloading toolz-0.9.0.tar.gz (45 kB)
#      |████████████████████████████████| 45 kB 2.5 MB/s
# Requirement already satisfied: tornado==5.1.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 71)) (5.1.1)
# Collecting traitlets==4.3.2
#   Downloading traitlets-4.3.2-py2.py3-none-any.whl (74 kB)
#      |████████████████████████████████| 74 kB 2.3 MB/s
# Collecting wcwidth==0.1.7
#   Downloading wcwidth-0.1.7-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: webencodings==0.5.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 74)) (0.5.1)
# Collecting Werkzeug==0.14.1
#   Downloading Werkzeug-0.14.1-py2.py3-none-any.whl (322 kB)
#      |████████████████████████████████| 322 kB 70.1 MB/s
# Collecting widgetsnbextension==3.4.2
#   Downloading widgetsnbextension-3.4.2-py2.py3-none-any.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 70.9 MB/s
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython==7.3.0->-r requirements.txt (line 16)) (57.4.0)
# Requirement already satisfied: dask[array]>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image==0.14.2->-r requirements.txt (line 61)) (2.12.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard==1.14.0->-r requirements.txt (line 65)) (0.37.1)
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   Downloading tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488 kB)
#      |████████████████████████████████| 488 kB 55.0 MB/s
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14.0->-r requirements.txt (line 66)) (1.13.3)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14.0->-r requirements.txt (line 66)) (0.2.0)
# Collecting dask[array]>=1.0.0
#   Downloading dask-2022.1.1-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 65.6 MB/s
#   Downloading dask-2022.1.0-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 73.8 MB/s
#   Downloading dask-2021.12.0-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 71.2 MB/s
#   Downloading dask-2021.11.2-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 68.0 MB/s
#   Downloading dask-2021.11.1-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 66.7 MB/s
#   Downloading dask-2021.11.0-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 68.2 MB/s
#   Downloading dask-2021.10.0-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 70.1 MB/s
#   Downloading dask-2021.9.1-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 70.5 MB/s
#   Downloading dask-2021.9.0-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 74.7 MB/s
#   Downloading dask-2021.8.1-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 54.9 MB/s
#   Downloading dask-2021.8.0-py3-none-any.whl (995 kB)
#      |████████████████████████████████| 995 kB 77.9 MB/s
#   Downloading dask-2021.7.2-py3-none-any.whl (987 kB)
#      |████████████████████████████████| 987 kB 77.2 MB/s
#   Downloading dask-2021.7.1-py3-none-any.whl (984 kB)
#      |████████████████████████████████| 984 kB 65.1 MB/s
#   Downloading dask-2021.7.0-py3-none-any.whl (977 kB)
#      |████████████████████████████████| 977 kB 65.0 MB/s
#   Downloading dask-2021.6.2-py3-none-any.whl (973 kB)
#      |████████████████████████████████| 973 kB 59.1 MB/s
#   Downloading dask-2021.6.1-py3-none-any.whl (973 kB)
#      |████████████████████████████████| 973 kB 62.0 MB/s
#   Downloading dask-2021.6.0-py3-none-any.whl (965 kB)
#      |████████████████████████████████| 965 kB 84.7 MB/s
#   Downloading dask-2021.5.1-py3-none-any.whl (964 kB)
#      |████████████████████████████████| 964 kB 72.3 MB/s
#   Downloading dask-2021.5.0-py3-none-any.whl (960 kB)
#      |████████████████████████████████| 960 kB 62.0 MB/s
#   Downloading dask-2021.4.1-py3-none-any.whl (952 kB)
#      |████████████████████████████████| 952 kB 66.1 MB/s
#   Downloading dask-2021.4.0-py3-none-any.whl (941 kB)
#      |████████████████████████████████| 941 kB 66.4 MB/s
#   Downloading dask-2021.3.1-py3-none-any.whl (935 kB)
#      |████████████████████████████████| 935 kB 65.8 MB/s
#   Downloading dask-2021.3.0-py3-none-any.whl (925 kB)
#      |████████████████████████████████| 925 kB
#   Building wheel for pandocfilters (setup.py) ... done
#   Created wheel for pandocfilters: filename=pandocfilters-1.4.2-py3-none-any.whl size=7872 sha256=1e90dbbd011ecec857c7120891b29bd0fcdab8d8ba288b355d3a975c2592fc91
#   Stored in directory: /root/.cache/pip/wheels/63/99/01/9fe785b86d1e091a6b2a61e06ddb3d8eb1bc9acae5933d4740
#   Building wheel for prometheus-client (setup.py) ... done
#   Created wheel for prometheus-client: filename=prometheus_client-0.6.0-py3-none-any.whl size=39589 sha256=2a7fd62395ba18a87563d124c020bc3d40064e2e97434a16c94bf47a8aa724fe
#   Stored in directory: /root/.cache/pip/wheels/6e/d8/31/c7c67f483036e5841d084f1138abdc078ba7c390544aa0ef28
#   Building wheel for toolz (setup.py) ... done
#   Created wheel for toolz: filename=toolz-0.9.0-py3-none-any.whl size=53247 sha256=bb68244d39797844ca62f12273609199f3dcd59d6ea43216db38dfd33b702b5e
#   Stored in directory: /root/.cache/pip/wheels/58/85/f9/3a8ac8d6acedfb76fb78ed9dedd7b5c86dc5bfdef4b2427219
# Successfully built keras-contrib absl-py backcall gast networkx pandocfilters prometheus-client toolz
# Installing collected packages: six, decorator, wcwidth, traitlets, ptyprocess, parso, pyzmq, python-dateutil, Pygments, prompt-toolkit, pexpect, MarkupSafe, jupyter-core, jsonschema, jedi, backcall, testpath, pandocfilters, nbformat, jupyter-client, Jinja2, ipython, entrypoints, defusedxml, bleach, terminado, Send2Trash, prometheus-client, numpy, nbconvert, ipykernel, notebook, h5py, widgetsnbextension, Werkzeug, toolz, scipy, pyparsing, protobuf, Markdown, kiwisolver, Keras-Preprocessing, Keras-Applications, grpcio, dask, cycler, absl-py, tensorflow-estimator, tensorboard, qtconsole, PyWavelets, Pillow, pandas, networkx, matplotlib, Keras, jupyter-console, ipywidgets, gast, cloudpickle, astor, xarray, tensorflow, scikit-image, pydot, keras-contrib, appnope
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.5
#     Uninstalling wcwidth-0.2.5:
#       Successfully uninstalled wcwidth-0.2.5
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.1.1
#     Uninstalling traitlets-5.1.1:
#       Successfully uninstalled traitlets-5.1.1
#   Attempting uninstall: ptyprocess
#     Found existing installation: ptyprocess 0.7.0
#     Uninstalling ptyprocess-0.7.0:
#       Successfully uninstalled ptyprocess-0.7.0
#   Attempting uninstall: parso
#     Found existing installation: parso 0.8.3
#     Uninstalling parso-0.8.3:
#       Successfully uninstalled parso-0.8.3
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 22.3.0
#     Uninstalling pyzmq-22.3.0:
#       Successfully uninstalled pyzmq-22.3.0
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.2
#     Uninstalling python-dateutil-2.8.2:
#       Successfully uninstalled python-dateutil-2.8.2
#   Attempting uninstall: Pygments
#     Found existing installation: Pygments 2.6.1
#     Uninstalling Pygments-2.6.1:
#       Successfully uninstalled Pygments-2.6.1
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 1.0.18
#     Uninstalling prompt-toolkit-1.0.18:
#       Successfully uninstalled prompt-toolkit-1.0.18
#   Attempting uninstall: pexpect
#     Found existing installation: pexpect 4.8.0
#     Uninstalling pexpect-4.8.0:
#       Successfully uninstalled pexpect-4.8.0
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.0.1
#     Uninstalling MarkupSafe-2.0.1:
#       Successfully uninstalled MarkupSafe-2.0.1
#   Attempting uninstall: jupyter-core
#     Found existing installation: jupyter-core 4.9.1
#     Uninstalling jupyter-core-4.9.1:
#       Successfully uninstalled jupyter-core-4.9.1
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.3.3
#     Uninstalling jsonschema-4.3.3:
#       Successfully uninstalled jsonschema-4.3.3
#   Attempting uninstall: jedi
#     Found existing installation: jedi 0.18.1
#     Uninstalling jedi-0.18.1:
#       Successfully uninstalled jedi-0.18.1
#   Attempting uninstall: backcall
#     Found existing installation: backcall 0.2.0
#     Uninstalling backcall-0.2.0:
#       Successfully uninstalled backcall-0.2.0
#   Attempting uninstall: testpath
#     Found existing installation: testpath 0.5.0
#     Uninstalling testpath-0.5.0:
#       Successfully uninstalled testpath-0.5.0
#   Attempting uninstall: pandocfilters
#     Found existing installation: pandocfilters 1.5.0
#     Uninstalling pandocfilters-1.5.0:
#       Successfully uninstalled pandocfilters-1.5.0
#   Attempting uninstall: nbformat
#     Found existing installation: nbformat 5.1.3
#     Uninstalling nbformat-5.1.3:
#       Successfully uninstalled nbformat-5.1.3
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 5.3.5
#     Uninstalling jupyter-client-5.3.5:
#       Successfully uninstalled jupyter-client-5.3.5
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
#   Attempting uninstall: ipython
#     Found existing installation: ipython 5.5.0
#     Uninstalling ipython-5.5.0:
#       Successfully uninstalled ipython-5.5.0
#   Attempting uninstall: entrypoints
#     Found existing installation: entrypoints 0.4
#     Uninstalling entrypoints-0.4:
#       Successfully uninstalled entrypoints-0.4
#   Attempting uninstall: defusedxml
#     Found existing installation: defusedxml 0.7.1
#     Uninstalling defusedxml-0.7.1:
#       Successfully uninstalled defusedxml-0.7.1
#   Attempting uninstall: bleach
#     Found existing installation: bleach 4.1.0
#     Uninstalling bleach-4.1.0:
#       Successfully uninstalled bleach-4.1.0
#   Attempting uninstall: terminado
#     Found existing installation: terminado 0.13.1
#     Uninstalling terminado-0.13.1:
#       Successfully uninstalled terminado-0.13.1
#   Attempting uninstall: Send2Trash
#     Found existing installation: Send2Trash 1.8.0
#     Uninstalling Send2Trash-1.8.0:
#       Successfully uninstalled Send2Trash-1.8.0
#   Attempting uninstall: prometheus-client
#     Found existing installation: prometheus-client 0.13.1
#     Uninstalling prometheus-client-0.13.1:
#       Successfully uninstalled prometheus-client-0.13.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 5.6.1
#     Uninstalling nbconvert-5.6.1:
#       Successfully uninstalled nbconvert-5.6.1
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 4.10.1
#     Uninstalling ipykernel-4.10.1:
#       Successfully uninstalled ipykernel-4.10.1
#   Attempting uninstall: notebook
#     Found existing installation: notebook 5.3.1
#     Uninstalling notebook-5.3.1:
#       Successfully uninstalled notebook-5.3.1
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.5.2
#     Uninstalling widgetsnbextension-3.5.2:
#       Successfully uninstalled widgetsnbextension-3.5.2
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 1.0.1
#     Uninstalling Werkzeug-1.0.1:
#       Successfully uninstalled Werkzeug-1.0.1
#   Attempting uninstall: toolz
#     Found existing installation: toolz 0.11.2
#     Uninstalling toolz-0.11.2:
#       Successfully uninstalled toolz-0.11.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.7
#     Uninstalling pyparsing-3.0.7:
#       Successfully uninstalled pyparsing-3.0.7
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.17.3
#     Uninstalling protobuf-3.17.3:
#       Successfully uninstalled protobuf-3.17.3
#   Attempting uninstall: Markdown
#     Found existing installation: Markdown 3.3.6
#     Uninstalling Markdown-3.3.6:
#       Successfully uninstalled Markdown-3.3.6
#   Attempting uninstall: kiwisolver
#     Found existing installation: kiwisolver 1.3.2
#     Uninstalling kiwisolver-1.3.2:
#       Successfully uninstalled kiwisolver-1.3.2
#   Attempting uninstall: Keras-Preprocessing
#     Found existing installation: Keras-Preprocessing 1.1.2
#     Uninstalling Keras-Preprocessing-1.1.2:
#       Successfully uninstalled Keras-Preprocessing-1.1.2
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.43.0
#     Uninstalling grpcio-1.43.0:
#       Successfully uninstalled grpcio-1.43.0
#   Attempting uninstall: dask
#     Found existing installation: dask 2.12.0
#     Uninstalling dask-2.12.0:
#       Successfully uninstalled dask-2.12.0
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.11.0
#     Uninstalling cycler-0.11.0:
#       Successfully uninstalled cycler-0.11.0
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.0.0
#     Uninstalling absl-py-1.0.0:
#       Successfully uninstalled absl-py-1.0.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.7.0
#     Uninstalling tensorflow-estimator-2.7.0:
#       Successfully uninstalled tensorflow-estimator-2.7.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.7.0
#     Uninstalling tensorboard-2.7.0:
#       Successfully uninstalled tensorboard-2.7.0
#   Attempting uninstall: qtconsole
#     Found existing installation: qtconsole 5.2.2
#     Uninstalling qtconsole-5.2.2:
#       Successfully uninstalled qtconsole-5.2.2
#   Attempting uninstall: PyWavelets
#     Found existing installation: PyWavelets 1.2.0
#     Uninstalling PyWavelets-1.2.0:
#       Successfully uninstalled PyWavelets-1.2.0
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.5
#     Uninstalling pandas-1.3.5:
#       Successfully uninstalled pandas-1.3.5
#   Attempting uninstall: networkx
#     Found existing installation: networkx 2.6.3
#     Uninstalling networkx-2.6.3:
#       Successfully uninstalled networkx-2.6.3
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
#   Attempting uninstall: Keras
#     Found existing installation: keras 2.7.0
#     Uninstalling keras-2.7.0:
#       Successfully uninstalled keras-2.7.0
#   Attempting uninstall: jupyter-console
#     Found existing installation: jupyter-console 5.2.0
#     Uninstalling jupyter-console-5.2.0:
#       Successfully uninstalled jupyter-console-5.2.0
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.6.5
#     Uninstalling ipywidgets-7.6.5:
#       Successfully uninstalled ipywidgets-7.6.5
#   Attempting uninstall: gast
#     Found existing installation: gast 0.4.0
#     Uninstalling gast-0.4.0:
#       Successfully uninstalled gast-0.4.0
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 1.3.0
#     Uninstalling cloudpickle-1.3.0:
#       Successfully uninstalled cloudpickle-1.3.0
#   Attempting uninstall: astor
#     Found existing installation: astor 0.8.1
#     Uninstalling astor-0.8.1:
#       Successfully uninstalled astor-0.8.1
#   Attempting uninstall: xarray
#     Found existing installation: xarray 0.18.2
#     Uninstalling xarray-0.18.2:
#       Successfully uninstalled xarray-0.18.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.7.0
#     Uninstalling tensorflow-2.7.0:
#       Successfully uninstalled tensorflow-2.7.0
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.18.3
#     Uninstalling scikit-image-0.18.3:
#       Successfully uninstalled scikit-image-0.18.3
#   Attempting uninstall: pydot
#     Found existing installation: pydot 1.3.0
#     Uninstalling pydot-1.3.0:
#       Successfully uninstalled pydot-1.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-probability 0.15.0 requires cloudpickle>=1.3, but you have cloudpickle 0.8.0 which is incompatible.
# tensorflow-probability 0.15.0 requires gast>=0.3.2, but you have gast 0.2.2 which is incompatible.
# tensorflow-metadata 1.6.0 requires absl-py<2.0.0,>=0.9, but you have absl-py 0.7.0 which is incompatible.
# tensorflow-metadata 1.6.0 requires protobuf<4,>=3.13, but you have protobuf 3.6.1 which is incompatible.
# tensorflow-hub 0.12.0 requires protobuf>=3.8.0, but you have protobuf 3.6.1 which is incompatible.
# pyerfa 2.0.0.1 requires numpy>=1.17, but you have numpy 1.16.1 which is incompatible.
# pyarrow 6.0.1 requires numpy>=1.16.6, but you have numpy 1.16.1 which is incompatible.
# plotnine 0.6.0 requires matplotlib>=3.1.1, but you have matplotlib 3.0.2 which is incompatible.
# plotnine 0.6.0 requires pandas>=0.25.0, but you have pandas 0.24.2 which is incompatible.
# nbclient 0.5.10 requires jupyter-client>=6.1.5, but you have jupyter-client 5.2.4 which is incompatible.
# nbclient 0.5.10 requires nbformat>=5.0, but you have nbformat 4.4.0 which is incompatible.
# mizani 0.6.0 requires matplotlib>=3.1.1, but you have matplotlib 3.0.2 which is incompatible.
# mizani 0.6.0 requires pandas>=0.25.0, but you have pandas 0.24.2 which is incompatible.
# kapre 0.3.7 requires numpy>=1.18.5, but you have numpy 1.16.1 which is incompatible.
# kapre 0.3.7 requires tensorflow>=2.0.0, but you have tensorflow 1.14.0 which is incompatible.
# jupyterlab-pygments 0.1.2 requires pygments<3,>=2.4.1, but you have pygments 2.3.1 which is incompatible.
# jaxlib 0.1.71+cuda111 requires numpy>=1.18, but you have numpy 1.16.1 which is incompatible.
# jax 0.2.25 requires numpy>=1.18, but you have numpy 1.16.1 which is incompatible.
# gym 0.17.3 requires cloudpickle<1.7.0,>=1.2.0, but you have cloudpickle 0.8.0 which is incompatible.
# googleapis-common-protos 1.54.0 requires protobuf>=3.12.0, but you have protobuf 3.6.1 which is incompatible.
# google-colab 1.0.0 requires astor~=0.8.1, but you have astor 0.7.1 which is incompatible.
# google-colab 1.0.0 requires ipykernel~=4.10, but you have ipykernel 5.1.0 which is incompatible.
# google-colab 1.0.0 requires ipython~=5.5.0, but you have ipython 7.3.0 which is incompatible.
# google-colab 1.0.0 requires notebook~=5.3.0; python_version >= "3.0", but you have notebook 5.7.4 which is incompatible.
# google-colab 1.0.0 requires pandas>=1.1.0; python_version >= "3.0", but you have pandas 0.24.2 which is incompatible.
# google-colab 1.0.0 requires six~=1.15.0, but you have six 1.12.0 which is incompatible.
# google-api-python-client 1.12.10 requires six<2dev,>=1.13.0, but you have six 1.12.0 which is incompatible.
# google-api-core 1.26.3 requires protobuf>=3.12.0, but you have protobuf 3.6.1 which is incompatible.
# google-api-core 1.26.3 requires six>=1.13.0, but you have six 1.12.0 which is incompatible.
# flask 1.1.4 requires Jinja2<3.0,>=2.10.1, but you have jinja2 2.10 which is incompatible.
# flask 1.1.4 requires Werkzeug<2.0,>=0.15, but you have werkzeug 0.14.1 which is incompatible.
# fbprophet 0.7.1 requires pandas>=1.0.4, but you have pandas 0.24.2 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# bokeh 2.3.3 requires pillow>=7.1.0, but you have pillow 5.4.1 which is incompatible.
# astropy 4.3.1 requires numpy>=1.17, but you have numpy 1.16.1 which is incompatible.
# arviz 0.11.4 requires xarray>=0.16.1, but you have xarray 0.14.0 which is incompatible.
# altair 4.2.0 requires jsonschema>=3.0, but you have jsonschema 2.6.0 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed Jinja2-2.10 Keras-2.2.4 Keras-Applications-1.0.7 Keras-Preprocessing-1.0.9 Markdown-3.0.1 MarkupSafe-1.1.0 Pillow-5.4.1 PyWavelets-1.0.1 Pygments-2.3.1 Send2Trash-1.5.0 Werkzeug-0.14.1 absl-py-0.7.0 appnope-0.1.0 astor-0.7.1 backcall-0.1.0 bleach-3.1.0 cloudpickle-0.8.0 cycler-0.10.0 dask-1.1.1 decorator-4.3.2 defusedxml-0.5.0 entrypoints-0.3 gast-0.2.2 grpcio-1.18.0 h5py-2.9.0 ipykernel-5.1.0 ipython-7.3.0 ipywidgets-7.4.2 jedi-0.13.2 jsonschema-2.6.0 jupyter-client-5.2.4 jupyter-console-6.0.0 jupyter-core-4.4.0 keras-contrib-2.0.8 kiwisolver-1.0.1 matplotlib-3.0.2 nbconvert-5.4.1 nbformat-4.4.0 networkx-2.2 notebook-5.7.4 numpy-1.16.1 pandas-0.24.2 pandocfilters-1.4.2 parso-0.3.4 pexpect-4.6.0 prometheus-client-0.6.0 prompt-toolkit-2.0.9 protobuf-3.6.1 ptyprocess-0.6.0 pydot-1.4.1 pyparsing-2.3.1 python-dateutil-2.8.0 pyzmq-18.0.0 qtconsole-4.4.3 scikit-image-0.14.2 scipy-1.2.1 six-1.12.0 tensorboard-1.14.0 tensorflow-1.14.0 tensorflow-estimator-1.14.0 terminado-0.8.1 testpath-0.4.2 toolz-0.9.0 traitlets-4.3.2 wcwidth-0.1.7 widgetsnbextension-3.4.2 xarray-0.14.0

# %% [markdown]
# # VAE Training

# %% [markdown]
# ## imports

# %%
import os

from models.VAE import VariationalAutoencoder
from utils.loaders import load_mnist

# %%
# run params
SECTION = 'vae'
RUN_ID = '0002'
DATA_NAME = 'digits'
RUN_FOLDER = 'run/{}/'.format(SECTION)
RUN_FOLDER += '_'.join([RUN_ID, DATA_NAME])

if not os.path.exists(RUN_FOLDER):
    os.mkdir(RUN_FOLDER)
    os.mkdir(os.path.join(RUN_FOLDER, 'viz'))
    os.mkdir(os.path.join(RUN_FOLDER, 'images'))
    os.mkdir(os.path.join(RUN_FOLDER, 'weights'))

mode =  'build' #'load' #

# %% [markdown]
# ## data

# %%
(x_train, y_train), (x_test, y_test) = load_mnist()

# %% [markdown]
# ## architecture

# %%
vae = VariationalAutoencoder(
    input_dim = (28,28,1)
    , encoder_conv_filters = [32,64,64, 64]
    , encoder_conv_kernel_size = [3,3,3,3]
    , encoder_conv_strides = [1,2,2,1]
    , decoder_conv_t_filters = [64,64,32,1]
    , decoder_conv_t_kernel_size = [3,3,3,3]
    , decoder_conv_t_strides = [1,2,2,1]
    , z_dim = 2
)

if mode == 'build':
    vae.save(RUN_FOLDER)
else:
    vae.load_weights(os.path.join(RUN_FOLDER, 'weights/weights.h5'))

# %%
vae.encoder.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_input (InputLayer)     [(None, 28, 28, 1)]  0           []
#
#  encoder_conv_0 (Conv2D)        (None, 28, 28, 32)   320         ['encoder_input[0][0]']
#
#  leaky_re_lu_7 (LeakyReLU)      (None, 28, 28, 32)   0           ['encoder_conv_0[0][0]']
#
#  encoder_conv_1 (Conv2D)        (None, 14, 14, 64)   18496       ['leaky_re_lu_7[0][0]']
#
#  leaky_re_lu_8 (LeakyReLU)      (None, 14, 14, 64)   0           ['encoder_conv_1[0][0]']
#
#  encoder_conv_2 (Conv2D)        (None, 7, 7, 64)     36928       ['leaky_re_lu_8[0][0]']
#
#  leaky_re_lu_9 (LeakyReLU)      (None, 7, 7, 64)     0           ['encoder_conv_2[0][0]']
#
#  encoder_conv_3 (Conv2D)        (None, 7, 7, 64)     36928       ['leaky_re_lu_9[0][0]']
#
#  leaky_re_lu_10 (LeakyReLU)     (None, 7, 7, 64)     0           ['encoder_conv_3[0][0]']
#
#  flatten_1 (Flatten)            (None, 3136)         0           ['leaky_re_lu_10[0][0]']
#
#  mu (Dense)                     (None, 2)            6274        ['flatten_1[0][0]']
#
#  log_var (Dense)                (None, 2)            6274        ['flatten_1[0][0]']
#
#  encoder_output (Lambda)        (None, 2)            0           ['mu[0][0]',
#                                                                   'log_var[0][0]']
#
# ==================================================================================================
# Total params: 105,220
# Trainable params: 105,220
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
vae.decoder.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  decoder_input (InputLayer)  [(None, 2)]               0
#
#  dense_1 (Dense)             (None, 3136)              9408
#
#  reshape_1 (Reshape)         (None, 7, 7, 64)          0
#
#  decoder_conv_t_0 (Conv2DTra  (None, 7, 7, 64)         36928
#  nspose)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 7, 7, 64)          0
#
#  decoder_conv_t_1 (Conv2DTra  (None, 14, 14, 64)       36928
#  nspose)
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 14, 14, 64)        0
#
#  decoder_conv_t_2 (Conv2DTra  (None, 28, 28, 32)       18464
#  nspose)
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 28, 28, 32)        0
#
#  decoder_conv_t_3 (Conv2DTra  (None, 28, 28, 1)        289
#  nspose)
#
#  activation_1 (Activation)   (None, 28, 28, 1)         0
#
# =================================================================
# Total params: 102,017
# Trainable params: 102,017
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## training

# %%
LEARNING_RATE = 0.0005
R_LOSS_FACTOR = 1000

# %%
vae.compile(LEARNING_RATE, R_LOSS_FACTOR)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
BATCH_SIZE = 32
EPOCHS = 200
PRINT_EVERY_N_BATCHES = 100
INITIAL_EPOCH = 1

# %%
vae.train(     
    x_train
    , batch_size = BATCH_SIZE
    , epochs = EPOCHS
    , run_folder = RUN_FOLDER
    , print_every_n_batches = PRINT_EVERY_N_BATCHES
    , initial_epoch = INITIAL_EPOCH
    )
# Out:
# Epoch 2/200
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-567b4dbb1076> in <module>()
#       5     , run_folder = RUN_FOLDER
#       6     , print_every_n_batches = PRINT_EVERY_N_BATCHES
# ----> 7     , initial_epoch = INITIAL_EPOCH
#       8     )
#
# /content/drive/MyDrive/GAN/GAN2_Src/models/VAE.py in train(self, x_train, batch_size, epochs, run_folder, print_every_n_batches, initial_epoch, lr_decay)
#     200             , epochs = epochs
#     201             , initial_epoch = initial_epoch
# --> 202             , callbacks = callbacks_list
#     203         )
#     204
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in autograph_handler(*args, **kwargs)
#
# TypeError: in user code:
#
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 867, in step_function  **
#         of index `epochs` is reached.
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 860, in run_step  **
#         epochs: Integer. Number of epochs to train the model.
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 810, in train_step
#         else:
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/compile_utils.py", line 240, in __call__
#
#     File "/usr/local/lib/python3.7/dist-packages/keras/utils/metrics_utils.py", line 73, in decorated
#
#     File "/usr/local/lib/python3.7/dist-packages/keras/metrics.py", line 177, in update_state_fn
#
#     File "/usr/local/lib/python3.7/dist-packages/keras/metrics.py", line 452, in update_state  **
#
#     File "/usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py", line 83, in asarray
#
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/keras_tensor.py", line 256, in __array__
#
#
#     TypeError: You are passing KerasTensor(type_spec=TensorSpec(shape=(), dtype=tf.float32, name=None), name='Placeholder:0', description="created by layer 'tf.cast_24'"), an intermediate Keras symbolic input/output, to a TF API that does not allow registering custom dispatchers, such as `tf.cond`, `tf.function`, gradient tapes, or `tf.map_fn`. Keras Functional model construction only supports TF API calls that *do* support dispatching, such as `tf.math.add` or `tf.reshape`. Other APIs cannot be called directly on symbolic Kerasinputs/outputs. You can work around this limitation by putting the operation in a custom Keras layer `call` and calling that layer on this symbolic input/output.

# %%
__num

# %% [markdown]
# # VAE Analysis

# %% [markdown]
# ## imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import os
from scipy.stats import norm

from models.VAE import VariationalAutoencoder
from utils.loaders import load_mnist, load_model

# %%
# run params
SECTION = 'vae'
RUN_ID = '0002'
DATA_NAME = 'digits'
RUN_FOLDER = 'run/{}/'.format(SECTION)
RUN_FOLDER += '_'.join([RUN_ID, DATA_NAME])

# %% [markdown]
# ## data

# %%
(x_train, y_train), (x_test, y_test) = load_mnist()

# %% [markdown]
# ## architecture

# %%
vae = load_model(VariationalAutoencoder, RUN_FOLDER)

# %% [markdown]
# ## reconstructing original paintings

# %%
n_to_show = 10
example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]

z_points = vae.encoder.predict(example_images)

reconst_images = vae.decoder.predict(z_points)

fig = plt.figure(figsize=(15, 3))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(n_to_show):
    img = example_images[i].squeeze()
    sub = fig.add_subplot(2, n_to_show, i+1)
    sub.axis('off')
    sub.text(0.5, -0.35, str(np.round(z_points[i],1)), fontsize=10, ha='center', transform=sub.transAxes)
            
    sub.imshow(img, cmap='gray_r')

for i in range(n_to_show):
    img = reconst_images[i].squeeze()
    sub = fig.add_subplot(2, n_to_show, i+n_to_show+1)
    sub.axis('off')
    sub.imshow(img, cmap='gray_r')
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f587f35bb00> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: list index out of range
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f587f35bb00> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: list index out of range
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f587f406560> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: list index out of range
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f587f406560> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: list index out of range
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %% [markdown]
# ## Mr N. Coder's wall

# %%
n_to_show = 5000
figsize = 12

example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]
example_labels = y_test[example_idx]

z_points = vae.encoder.predict(example_images)

min_x = min(z_points[:, 0])
max_x = max(z_points[:, 0])
min_y = min(z_points[:, 1])
max_y = max(z_points[:, 1])

plt.figure(figsize=(figsize, figsize))
plt.scatter(z_points[:, 0] , z_points[:, 1], c='black', alpha=0.5, s=2)
plt.show()

# %% [markdown]
# ### The new generated art exhibition

# %%
figsize = 8
plt.figure(figsize=(figsize, figsize))
plt.scatter(z_points[:, 0] , z_points[:, 1], c='black', alpha=0.5, s=2)


grid_size = 15
grid_depth = 2
figsize = 15

x = np.random.normal(size = grid_size * grid_depth)
y = np.random.normal(size = grid_size * grid_depth)

z_grid = np.array(list(zip(x, y)))
reconst = vae.decoder.predict(z_grid)

plt.scatter(z_grid[:, 0] , z_grid[:, 1], c = 'red', alpha=1, s=20)
plt.show()

fig = plt.figure(figsize=(figsize, grid_depth))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(grid_size*grid_depth):
    ax = fig.add_subplot(grid_depth, grid_size, i+1)
    ax.axis('off')
    ax.text(0.5, -0.35, str(np.round(z_grid[i],1)), fontsize=8, ha='center', transform=ax.transAxes)
    
    ax.imshow(reconst[i, :,:,0], cmap = 'Greys')

# %%
n_to_show = 5000
grid_size = 15
fig_height = 7
fig_width = 15

example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]
example_labels = y_test[example_idx]

z_points = vae.encoder.predict(example_images)
p_points = norm.cdf(z_points)

fig = plt.figure(figsize=(fig_width, fig_height))

ax = fig.add_subplot(1, 2, 1)
plot_1 = ax.scatter(z_points[:, 0] , z_points[:, 1] , cmap='rainbow' , c= example_labels
            , alpha=0.5, s=2)
plt.colorbar(plot_1)

ax = fig.add_subplot(1, 2, 2)
plot_2 = ax.scatter(p_points[:, 0] , p_points[:, 1] , cmap='rainbow' , c= example_labels
            , alpha=0.5, s=5)



plt.show()

# %%
n_to_show = 5000
grid_size = 20
figsize = 8

example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]
example_labels = y_test[example_idx]

z_points = vae.encoder.predict(example_images)

plt.figure(figsize=(5, 5))
plt.scatter(z_points[:, 0] , z_points[:, 1] , cmap='rainbow' , c= example_labels
            , alpha=0.5, s=2)
plt.colorbar()

x = norm.ppf(np.linspace(0.01, 0.99, grid_size))
y = norm.ppf(np.linspace(0.01, 0.99, grid_size))
xv, yv = np.meshgrid(x, y)
xv = xv.flatten()
yv = yv.flatten()
z_grid = np.array(list(zip(xv, yv)))

reconst = vae.decoder.predict(z_grid)

plt.scatter(z_grid[:, 0] , z_grid[:, 1], c = 'black'#, cmap='rainbow' , c= example_labels
            , alpha=1, s=2)




plt.show()


fig = plt.figure(figsize=(figsize, figsize))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(grid_size**2):
    ax = fig.add_subplot(grid_size, grid_size, i+1)
    ax.axis('off')
    ax.imshow(reconst[i, :,:,0], cmap = 'Greys')
